# %% [markdown]
# <div class="alert alert-block alert-success">
#
# # Imperial Business Analytics- WK8- Estimators
#
#  👨‍🏫 **Vikesh K**
#  📅 **[02-Jan-2023]** ⏰ **7pm UTC**
#  #️⃣ **Office Hour # 07**
#
#
#
# </div>

# %% [markdown]
#  💡  <span style='font-family:Georgia'>
#     <font color= darkred> ***It doesn't get easier, you get better- Unknown***
#     </font> 💡

# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Imperial-Business-Analytics--WK8--Estimators" data-toc-modified-id="Imperial-Business-Analytics--WK8--Estimators-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Imperial Business Analytics- WK8- Estimators</a></span></li><li><span><a href="#OH-Agenda-📝" data-toc-modified-id="OH-Agenda-📝-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>OH Agenda 📝</a></span></li><li><span><a href="#▶️-Theory" data-toc-modified-id="▶️-Theory-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>▶️ Theory</a></span></li><li><span><a href="#Case-Study-📓---Instacart" data-toc-modified-id="Case-Study-📓---Instacart-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Case Study 📓 - Instacart</a></span><ul class="toc-item"><li><span><a href="#Note:-✨" data-toc-modified-id="Note:-✨-4.1"><span class="toc-item-num">4.1&nbsp;&nbsp;</span>Note: ✨</a></span></li><li><span><a href="#Loading-the-modules" data-toc-modified-id="Loading-the-modules-4.2"><span class="toc-item-num">4.2&nbsp;&nbsp;</span>Loading the modules</a></span></li><li><span><a href="#Importing-the-data" data-toc-modified-id="Importing-the-data-4.3"><span class="toc-item-num">4.3&nbsp;&nbsp;</span>Importing the data</a></span></li><li><span><a href="#Exercises-💥⚡" data-toc-modified-id="Exercises-💥⚡-4.4"><span class="toc-item-num">4.4&nbsp;&nbsp;</span>Exercises 💥⚡</a></span><ul class="toc-item"><li><span><a href="#Importing-data-in-the-correct-way" data-toc-modified-id="Importing-data-in-the-correct-way-4.4.1"><span class="toc-item-num">4.4.1&nbsp;&nbsp;</span>Importing data in the correct way</a></span></li></ul></li><li><span><a href="#Data-Cleaning" data-toc-modified-id="Data-Cleaning-4.5"><span class="toc-item-num">4.5&nbsp;&nbsp;</span>Data Cleaning</a></span></li><li><span><a href="#Exploring-the-delivery-time-across-regions" data-toc-modified-id="Exploring-the-delivery-time-across-regions-4.6"><span class="toc-item-num">4.6&nbsp;&nbsp;</span>Exploring the delivery time across regions</a></span><ul class="toc-item"><li><span><a href="#Plot-the-deliveries-in-sf" data-toc-modified-id="Plot-the-deliveries-in-sf-4.6.1"><span class="toc-item-num">4.6.1&nbsp;&nbsp;</span>Plot the deliveries in <code>sf</code></a></span></li><li><span><a href="#Plot-the-deliveries-in-all-regions" data-toc-modified-id="Plot-the-deliveries-in-all-regions-4.6.2"><span class="toc-item-num">4.6.2&nbsp;&nbsp;</span>Plot the deliveries in all regions</a></span></li></ul></li></ul></li></ul></div>

# %% [markdown]
# <div class="alert alert-block alert-success">
#
# # OH Agenda 📝
#
# * **Instacart case study** : Analysing an open ended data analytics problem
# * Understanding the time series in pandas
# * Coding exercises 💥⚡
#
# <div/>

# %% [markdown]
# <div class="alert alert-block alert-danger">
#
# # ▶️ Theory
#
#
#
#
# **Data Science reality**
#
# ![data_science_reality.png](attachment:data_science_reality.png)

# %% [markdown]
# # Case Study 📓 - Instacart
#
# ![instacart_logo.png](attachment:instacart_logo.png)

# %% [markdown]
# <div class="alert alert-block alert-info">
#
# ## Note: ✨
#
# A **take-home assignment** is a coding task given to candidates to complete on their own time. Candidates are typically given a day to several days to complete a take-home. It is done to understand a candidate's problem solving approach and how they structure a business problem, solve it using data and give back business recommendations.
#
# In this OH, we will analyze a problem posed by [**Instacart**](https://www.instacart.com/) for its Data Analyst position. You can download the challenge from [here](https://github.com/vkoul/data/blob/main/misc/Instacart_Data_Analyst_Challenge.xlsx) and refer to OH recording to understand the approach.
#
# The next step was to do data analysis using Python and this is where this jupyter notebook comes in
#
# <div/>

# %% [markdown]
# 💡 **We will learn about the data used by delivery companies and how they analyze it to solve their business problems**

# %% [markdown]
# ## Loading the modules

# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import seaborn as sns
plt.style.use('fivethirtyeight')
# %matplotlib inline

import warnings
warnings.filterwarnings("ignore")

import os 
os.getcwd() # make sure the zip file is saved in the working directory
# Out:
# "C:\\Users\\vkoul\\Downloads\\Learning\\03-IMP_BA\\IMPBA Nov'22-Mar'23\\WK07"

# %% [markdown]
# ## Importing the data

# %%
url = 'https://raw.githubusercontent.com/vkoul/data/main/misc/instacart.csv'

df = pd.read_csv(url)
orig_df = df # create a copy of the original data-frame

# %%
df.shape
# Out:
# (14957, 5)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14957 entries, 0 to 14956
# Data columns (total 5 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   order_delivery_time      14957 non-null  object
#  1   order_id                 14957 non-null  int64
#  2   customer_order_rating    14957 non-null  int64
#  3   type_of_issue _reported  1087 non-null   object
#  4   region                   14957 non-null  object
# dtypes: int64(2), object(3)
# memory usage: 584.4+ KB

# %%
df.head()
# Out:
#        order_delivery_time   order_id  customer_order_rating  \
# 0  2014-06-02 04:23:16 UTC  233599337                      5
# 1  2014-06-02 03:57:50 UTC  233599376                      5
# 2  2014-06-02 02:52:38 UTC  233599328                      5
# 3  2014-06-02 02:52:04 UTC  233599070                      5
# 4  2014-06-02 02:41:43 UTC  233599100                      5
#
#   type_of_issue _reported region
# 0                     NaN    chi
# 1                     NaN    chi
# 2                     NaN    chi
# 3                     NaN    chi
# 4                     NaN    chi

# %% [markdown]
# ## Exercises 💥⚡

# %% [markdown]
# ❓**Are there any missing values in the dataset?**

# %%
df.isna().sum()
# Out:
# order_delivery_time            0
# order_id                       0
# customer_order_rating          0
# type_of_issue _reported    13870
# region                         0
# dtype: int64

# %% [markdown]
# ❓**Are there any duplicates in the dataset? Please treat them**

# %%
df.duplicated().sum()
# Out:
# 123

# %%
df.drop_duplicates(inplace = True)

# %%
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# **Cleaning column names**

# %%
df.columns = ['order_delivery_time', 'order_id', 'customer_order_rating',
       'type_of_issue_reported', 'region']

# %%
df.columns
# Out:
# Index(['order_delivery_time', 'order_id', 'customer_order_rating',
#        'type_of_issue_reported', 'region'],
#       dtype='object')

# %% [markdown]
# **Duplicates at `Order ID` level**

# %%
# df[df['order_id'].duplicated(keep= False)].sort_values(by = 'order_id')

# %%
# exporting the files
# df[df['order_id'].duplicated(keep= False)].sort_values(by = 'order_id').to_csv("duplicate_case.csv", index = False)

# %% [markdown]
# ### Importing data in the correct way

# %% [markdown]
# <div class="alert alert-block alert-danger">
#
# **The challenge in the above dataset is that, `order_delivery_time` has been wrongly classified as an object. We need to put it in the right format (time) before we can use the column for further analysis.**
#
# **We will make use of the arguments within the [`pd.read_csv()`function](https://pandas.pydata.org/docs/reference/api/pandas.read_csv.html) to read in the delivery column as a time object**
#
# **In the `date_parser` we are specifying the function that we need to choose, the `utc = True` argument is choosen as the delivery time is given in a [utc time format](https://en.wikipedia.org/wiki/Coordinated_Universal_Time)**
#
# <div/>

# %%
df2 = pd.read_csv(url
                  ,parse_dates = ['order_delivery_time'] # specifies the column
                  ,date_parser = lambda col: pd.to_datetime(col, utc=True)) # which function to apply to it

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14957 entries, 0 to 14956
# Data columns (total 5 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   order_delivery_time      14957 non-null  datetime64[ns, UTC]
#  1   order_id                 14957 non-null  int64
#  2   customer_order_rating    14957 non-null  int64
#  3   type_of_issue _reported  1087 non-null   object
#  4   region                   14957 non-null  object
# dtypes: datetime64[ns, UTC](1), int64(2), object(2)
# memory usage: 584.4+ KB

# %%
df2.head()
# Out:
#         order_delivery_time   order_id  customer_order_rating  \
# 0 2014-06-02 04:23:16+00:00  233599337                      5
# 1 2014-06-02 03:57:50+00:00  233599376                      5
# 2 2014-06-02 02:52:38+00:00  233599328                      5
# 3 2014-06-02 02:52:04+00:00  233599070                      5
# 4 2014-06-02 02:41:43+00:00  233599100                      5
#
#   type_of_issue _reported region
# 0                     NaN    chi
# 1                     NaN    chi
# 2                     NaN    chi
# 3                     NaN    chi
# 4                     NaN    chi

# %% [markdown]
# ## Data Cleaning

# %%
df2['region'].unique().tolist() # the tolist() gives the output in a list format
# Out:
# ['chi', 'nyc', 'sf', 'sf ']

# %% [markdown]
# **In the above list, you can see that there are two enteries for `sf`. Its because there is a whitespace in the data. We need to remove it, before we can do the analysis.**
# **We will make use of a string function [`str.strip()`](https://pandas.pydata.org/pandas-docs/version/1.2.4/reference/api/pandas.Series.str.strip.html) to do it**

# %%
df2['region'] = df2['region'].str.strip()

# %%
df2['region'].unique().tolist()
# Out:
# ['chi', 'nyc', 'sf']

# %% [markdown]
# **The problem of multiple `sf` versions is solved**

# %% [markdown]
# ## Exploring the delivery time across regions

# %% [markdown]
# 💡**We can extract different elements from a time column like date, hour, minutes, weekday etc. We will extract the hour**

# %%
df2["hour"] = df2['order_delivery_time'].dt.hour

# %%
df2.head()
# Out:
#         order_delivery_time   order_id  customer_order_rating  \
# 0 2014-06-02 04:23:16+00:00  233599337                      5
# 1 2014-06-02 03:57:50+00:00  233599376                      5
# 2 2014-06-02 02:52:38+00:00  233599328                      5
# 3 2014-06-02 02:52:04+00:00  233599070                      5
# 4 2014-06-02 02:41:43+00:00  233599100                      5
#
#   type_of_issue _reported region  hour
# 0                     NaN    chi     4
# 1                     NaN    chi     3
# 2                     NaN    chi     2
# 3                     NaN    chi     2
# 4                     NaN    chi     2

# %% [markdown]
# <div class="alert alert-block alert-danger">
#
# 💡 **[Good to know] Pandas also allows you to highlight cells/rows/columns to highlight specific aspects of your data. This is done using styling.Let's generate the head view again, highlighting the new column that we created. Read more. [here](https://pandas.pydata.org/pandas-docs/stable/user_guide/style.html)**
#
# <div/>

# %%
df2.head().style.set_properties(**{'background-color': 'darkred',
                                   'color': 'white',
                                   'border-color': 'white'}, subset= ['hour'])
# Out:
# <style type="text/css">
# #T_4c15a_row0_col5, #T_4c15a_row1_col5, #T_4c15a_row2_col5, #T_4c15a_row3_col5, #T_4c15a_row4_col5 {
#   background-color: darkred;
#   color: white;
#   border-color: white;
# }
# </style>
# <table id="T_4c15a">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_4c15a_level0_col0" class="col_heading level0 col0" >order_delivery_time</th>
#       <th id="T_4c15a_level0_col1" class="col_heading level0 col1" >order_id</th>
#       <th id="T_4c15a_level0_col2" class="col_heading level0 col2" >customer_order_rating</th>
#       <th id="T_4c15a_level0_col3" class="col_heading level0 col3" >type_of_issue _reported</th>
#       <th id="T_4c15a_level0_col4" class="col_heading level0 col4" >region</th>
#       <th id="T_4c15a_level0_col5" class="col_heading level0 col5" >hour</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_4c15a_level0_row0" class="row_heading level0 row0" >0</th>
# ...

# %% [markdown]
# ### Plot the deliveries in `sf`

# %%
# slicing for san franciso
sf = df2[df2['region'] == "sf"]

# %%
# customise chart
plt.figure(figsize = (10, 5))

# plot the data 
sf.groupby('hour')['order_id'].count().plot(kind = 'line', label = "sf")

# customise chart
plt.title("Count of deliveries across region")
plt.xlabel("hour")
plt.ylabel("delivery count")

plt.legend()
plt.show();

# %% [markdown]
# ### Plot the deliveries in all regions

# %% [markdown]
# **Using a loop to generate multiple charts**: We can use the above code used and put it in a loop to plot for all the regions

# %%
region_list = df2['region'].unique().tolist()

print(region_list)
# Out:
# ['chi', 'nyc', 'sf']

# %% [markdown]
# **We will use different ways to generate the charts**

# %%
for region in region_list:
    (df2[df2['region'] == region]
     .groupby('hour')['order_id']
     .count()
     .plot(kind = 'line', title = 'All regions in one chart')
    )

# %% [markdown]
# **Separating the regions across charts**

# %% [markdown]
# <div class="alert alert-block alert-success">
#
# **For producing charts in loop, using the `df[column] == condition` is much more straight forward than the `df.query()` method. Hence, I altered the code we tried in the OH**

# %%
for region in region_list:
    (df2[df2['region'] == region]
     .groupby('hour')['order_id']
     .count()
     .plot(kind = 'line', title = region)
    );
    plt.figure();

# %% [markdown]
# **Further formatting the chart**

# %%
# loop for the multiple regions
for region in region_list: # intiate the loop
    
    plt.figure(figsize = (10, 5))
    df2[df2['region'] == region].groupby('hour')['order_id'].count().plot(kind = 'line')
    
    # labels
    plt.title("Count of deliveries across " + region) # to update the title dynamically
    plt.xlabel("hour")
    plt.ylabel("delivery count")
    
    plt.show();

# %% [markdown]
# <div class="alert alert-block alert-danger">
#
# **The order delivery trend look odd. Most of the order seems to be happening at very early hours. You will notice that the `order_delivery_time` is currently measure in the UTC format. We would need to convert it to a local time zone based on the location before we can do our data analysis. We will use `dt.tz_convert()` within pandas to do this. As an argument, we specify the time zone to which it needs to be converted**
#
# <div/>

# %% [markdown]
# **We can change the time zones. The options we will choose are : `US/Eastern`, `US/Pacific`, `US/Central`**

# %% [markdown]
# ![us_time_zone-3.jpg](attachment:us_time_zone-3.jpg)

# %% [markdown]
# <div class="alert alert-block alert-danger">
#
# **You can use `np.where()` to convert the time zone on the overall dataset or seperate it by region, make the conversions and join it back togther**

# %%
# creating new columns
sf['local_time'] = sf['order_delivery_time'].dt.tz_convert('US/Pacific')
sf['local_hour'] = sf['local_time'].dt.hour

# %%
# exploring the new columns
sf.head().style.set_properties(**{'background-color': 'darkred',
                                   'color': 'white',
                                   'border-color': 'white'}, subset= ['local_time', 'local_hour'])
# Out:
# <style type="text/css">
# #T_a8d0e_row0_col6, #T_a8d0e_row0_col7, #T_a8d0e_row1_col6, #T_a8d0e_row1_col7, #T_a8d0e_row2_col6, #T_a8d0e_row2_col7, #T_a8d0e_row3_col6, #T_a8d0e_row3_col7, #T_a8d0e_row4_col6, #T_a8d0e_row4_col7 {
#   background-color: darkred;
#   color: white;
#   border-color: white;
# }
# </style>
# <table id="T_a8d0e">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_a8d0e_level0_col0" class="col_heading level0 col0" >order_delivery_time</th>
#       <th id="T_a8d0e_level0_col1" class="col_heading level0 col1" >order_id</th>
#       <th id="T_a8d0e_level0_col2" class="col_heading level0 col2" >customer_order_rating</th>
#       <th id="T_a8d0e_level0_col3" class="col_heading level0 col3" >type_of_issue _reported</th>
#       <th id="T_a8d0e_level0_col4" class="col_heading level0 col4" >region</th>
#       <th id="T_a8d0e_level0_col5" class="col_heading level0 col5" >hour</th>
# ...

# %%
# plotting the data
plt.figure(figsize = (10, 5))

sf.groupby('local_hour')['order_id'].count().plot(kind = 'line')

plt.title("Delivery count in sf; local time");

# %% [markdown]
# **Similar to `sf`, please make convert the data for `chi` and `nyc`. Make use of the appropriate US time-zones. Refer to image below**

# %% [markdown]
# **Extract different time elements from the time column**

# %%
# Extract the different elements . Uncomment the codes below

# date
print(df2['order_delivery_time'].dt.date, '\n')

# time
print(df2['order_delivery_time'].dt.time, '\n')

# hour
print(df2['order_delivery_time'].dt.hour, '\n')

# minute
print(df2['order_delivery_time'].dt.minute, '\n')

# weekday
print(df2['order_delivery_time'].dt.day_name(), '\n')
# Out:
# 0        2014-06-02
# 1        2014-06-02
# 2        2014-06-02
# 3        2014-06-02
# 4        2014-06-02
#             ...
# 14952    2014-05-07
# 14953    2014-05-05
# 14954    2014-05-04
# 14955    2014-05-03
# 14956    2014-05-01
# Name: order_delivery_time, Length: 14957, dtype: object
#
# 0        04:23:16
# 1        03:57:50
# 2        02:52:38
# 3        02:52:04
# 4        02:41:43
#            ...
# 14952    20:29:32
# 14953    23:59:17
# 14954    22:48:29
# 14955    17:41:36
# 14956    23:25:46
# Name: order_delivery_time, Length: 14957, dtype: object
#
# 0         4
# 1         3
# 2         2
# 3         2
# 4         2
#          ..
# 14952    20
# 14953    23
# 14954    22
# 14955    17
# 14956    23
# Name: order_delivery_time, Length: 14957, dtype: int64
#
# 0        23
# 1        57
# 2        52
# 3        52
# 4        41
#          ..
# 14952    29
# 14953    59
# 14954    48
# 14955    41
# 14956    25
# Name: order_delivery_time, Length: 14957, dtype: int64
# ...

# %% [markdown]
# <div class="alert alert-block alert-danger">
#
# **Please continue with the rest of the analysis based on what we discussed in the Office hour. Remember the end aim. You need to have actionable insights to solve the problem of customer support team staffing and make observations about the business.**
