# %% [markdown]
# <div class="alert alert-block alert-success">
#
#
# # Imperial Business Analytics OH: WK13- Clustering
#
#  👨‍🏫 **Vikesh K**
#  📅 **[06-Feb-2023]** ⏰ **7pm UTC**
#   **Office Hour # 12**
#
#
# </div>

# %% [markdown]
# <div class="alert alert-block alert-danger">
#
# # OH Agenda 📝
#
# We will cover:
#
# * Customer Segmentation
# * Action Plan\
# * EDA
# * Data Preprocessing
# * Modeling
#
#
#  </div>

# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Imperial-Business-Analytics-OH:-WK13--Clustering" data-toc-modified-id="Imperial-Business-Analytics-OH:-WK13--Clustering-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Imperial Business Analytics OH: WK13- Clustering</a></span></li><li><span><a href="#OH-Agenda-📝" data-toc-modified-id="OH-Agenda-📝-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>OH Agenda 📝</a></span></li><li><span><a href="#Case-Study-📓:-Customer-Segmentation-and-Targeting" data-toc-modified-id="Case-Study-📓:-Customer-Segmentation-and-Targeting-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Case Study 📓: Customer Segmentation and Targeting</a></span><ul class="toc-item"><li><span><a href="#-Import-modules-and-data-" data-toc-modified-id="-Import-modules-and-data--3.1"><span class="toc-item-num">3.1&nbsp;&nbsp;</span><font color="darkred"> Import modules and data </font></a></span></li><li><span><a href="#-Data-Inspection🔍📊" data-toc-modified-id="-Data-Inspection🔍📊-3.2"><span class="toc-item-num">3.2&nbsp;&nbsp;</span><font color="darkred"> Data Inspection</font>🔍📊</a></span><ul class="toc-item"><li><span><a href="#-Numerical-inspection-and-summaries-" data-toc-modified-id="-Numerical-inspection-and-summaries--3.2.1"><span class="toc-item-num">3.2.1&nbsp;&nbsp;</span><font color="darkred"> Numerical inspection and summaries </font></a></span></li></ul></li><li><span><a href="#-EDA-" data-toc-modified-id="-EDA--3.3"><span class="toc-item-num">3.3&nbsp;&nbsp;</span><font color="darkred"> EDA </font></a></span><ul class="toc-item"><li><span><a href="#Univariate-Analysis" data-toc-modified-id="Univariate-Analysis-3.3.1"><span class="toc-item-num">3.3.1&nbsp;&nbsp;</span>Univariate Analysis</a></span></li><li><span><a href="#Bivariate-Analysis" data-toc-modified-id="Bivariate-Analysis-3.3.2"><span class="toc-item-num">3.3.2&nbsp;&nbsp;</span>Bivariate Analysis</a></span></li></ul></li><li><span><a href="#-Data-Prep-for-Modeling-" data-toc-modified-id="-Data-Prep-for-Modeling--3.4"><span class="toc-item-num">3.4&nbsp;&nbsp;</span><font color="darkred"> Data Prep for Modeling </font></a></span><ul class="toc-item"><li><span><a href="#Scaling-Data" data-toc-modified-id="Scaling-Data-3.4.1"><span class="toc-item-num">3.4.1&nbsp;&nbsp;</span>Scaling Data</a></span></li><li><span><a href="#Convert-categorical-value-to-numerical" data-toc-modified-id="Convert-categorical-value-to-numerical-3.4.2"><span class="toc-item-num">3.4.2&nbsp;&nbsp;</span>Convert categorical value to numerical</a></span></li></ul></li><li><span><a href="#-Model-building--💥⚡" data-toc-modified-id="-Model-building--💥⚡-3.5"><span class="toc-item-num">3.5&nbsp;&nbsp;</span><font color="darkred"> Model building </font> 💥⚡</a></span><ul class="toc-item"><li><span><a href="#Clustering-using-KMeans" data-toc-modified-id="Clustering-using-KMeans-3.5.1"><span class="toc-item-num">3.5.1&nbsp;&nbsp;</span>Clustering using <a href="https://scikit-learn.org/stable/modules/generated/sklearn.cluster.KMeans.html" rel="nofollow" target="_blank">KMeans</a></a></span></li><li><span><a href="#Optimal-Clusters-using-Elbow-Method" data-toc-modified-id="Optimal-Clusters-using-Elbow-Method-3.5.2"><span class="toc-item-num">3.5.2&nbsp;&nbsp;</span>Optimal Clusters using Elbow Method</a></span></li></ul></li><li><span><a href="#Cluster-Level-Analysis" data-toc-modified-id="Cluster-Level-Analysis-3.6"><span class="toc-item-num">3.6&nbsp;&nbsp;</span>Cluster Level Analysis</a></span></li></ul></li><li><span><a href="#Reference-material-📚" data-toc-modified-id="Reference-material-📚-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Reference material 📚</a></span></li></ul></div>

# %% [markdown]
# <div class="alert alert-block alert-success">
#
# # Case Study 📓: Customer Segmentation and Targeting
#
# [Case Study Link](https://docs.google.com/document/d/1AvUydV8er-qNNTwTlH8ITMLpX-29t14wc3wvFQX2goY/edit?usp=sharing)
#
#
# </div>

# %% [markdown]
# ##  <font color= darkred> Import modules and data </font>

# %%
# data manipulation
import pandas as pd
import numpy as np

# data viz
import matplotlib.pyplot as plt
import seaborn as sns
plt.style.use("fivethirtyeight") # styling the charts

import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# **Load Data**

# %%
url = 'https://raw.githubusercontent.com/vkoul/data/main/misc/household_data.csv'

df = pd.read_csv(url)

# %% [markdown]
# ##  <font color= darkred> Data Inspection</font>🔍📊

# %% [markdown]
# ### <font color= darkred> Numerical inspection and summaries </font>

# %% [markdown]
# **Data Inspect**

# %%
df.shape
# Out:
# (15000, 11)

# %%
df.head()
# Out:
#    householdID  total_ppl own_rent  square_foot  household_income  \
# 0            1          3      own         3309             80464
# 1            2          3      own         3814             47696
# 2            3          3     rent         2592            108256
# 3            4          2      own         2628             68064
# 4            5          3     rent         2442             62786
#
#    number_pets      county  entertainment_spend_est  travel_spend_est  \
# 0            1        York                     2535              2842
# 1            2        York                     2913              3938
# 2            2  Cumberland                     1986              3687
# 3            1  Cumberland                     2505              2826
# 4            2   Sagadahoc                     3541              1344
#
#    under_12 LL_passholder
# 0         1            No
# 1         1            No
# 2         2            No
# 3         1            No
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15000 entries, 0 to 14999
# Data columns (total 11 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   householdID              15000 non-null  int64
#  1   total_ppl                15000 non-null  int64
#  2   own_rent                 15000 non-null  object
#  3   square_foot              15000 non-null  int64
#  4   household_income         15000 non-null  int64
#  5   number_pets              15000 non-null  int64
#  6   county                   15000 non-null  object
#  7   entertainment_spend_est  15000 non-null  int64
#  8   travel_spend_est         15000 non-null  int64
#  9   under_12                 15000 non-null  int64
#  10  LL_passholder            15000 non-null  object
# dtypes: int64(8), object(3)
# memory usage: 1.3+ MB

# %% [markdown]
# **Missing values check**

# %%
df.isna().sum()
# Out:
# householdID                0
# total_ppl                  0
# own_rent                   0
# square_foot                0
# household_income           0
# number_pets                0
# county                     0
# entertainment_spend_est    0
# travel_spend_est           0
# under_12                   0
# LL_passholder              0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df = df.drop(columns = 'householdID').copy()

# %% [markdown]
# ##   <font color= darkred> EDA </font>

# %% [markdown]
# ### Univariate Analysis

# %%
df.describe()
# Out:
#           total_ppl   square_foot  household_income   number_pets  \
# count  15000.000000  15000.000000      15000.000000  15000.000000
# mean       3.130067   3118.928600      72555.562067      1.509200
# std        0.891592    815.925967      18758.466766      0.790163
# min        1.000000    370.000000       6801.000000      0.000000
# 25%        3.000000   2506.000000      60007.000000      1.000000
# 50%        3.000000   3042.000000      72512.000000      2.000000
# 75%        4.000000   3738.000000      85201.750000      2.000000
# max        7.000000   6081.000000     145381.000000      4.000000
#
#        entertainment_spend_est  travel_spend_est      under_12
# count             15000.000000      15000.000000  15000.000000
# mean               2651.515000       3556.169400      1.766533
# std                 766.499083        599.815642      0.732072
# min                 193.000000        924.000000      0.000000
# ...

# %%
df.describe(include = 'object')
# Out:
#        own_rent      county LL_passholder
# count     15000       15000         15000
# unique        2           3             2
# top         own  Cumberland            No
# freq      11306        8120          8837

# %%
object_cols = df.select_dtypes('object').columns.to_list()
object_cols
# Out:
# ['own_rent', 'county', 'LL_passholder']

# %%
for col in object_cols:
    print(col)
    df[col].value_counts(normalize = True).round(3).plot(kind = 'bar')
    plt.show()
# Out:
# own_rent
# county
# LL_passholder

# %%
df.hist(figsize=(18,8), grid = False);

# %% [markdown]
# ### Bivariate Analysis

# %% [markdown]
# **Numerical Summaries**

# %%
df.groupby('county').describe().T
# Out:
# county                            Cumberland      Sagadahoc           York
# total_ppl               count    8120.000000    1265.000000    5615.000000
#                         mean        3.126724       3.098024       3.142119
#                         std         0.889276       0.879552       0.897547
#                         min         1.000000       1.000000       1.000000
#                         25%         3.000000       3.000000       3.000000
#                         50%         3.000000       3.000000       3.000000
#                         75%         4.000000       4.000000       4.000000
#                         max         7.000000       6.000000       7.000000
# square_foot             count    8120.000000    1265.000000    5615.000000
#                         mean     2683.856404    2366.762055    3917.553161
#                         std       524.159125     547.527828     524.063740
# ...

# %%
# df.groupby('own_rent').describe().T

# %% [markdown]
# **Graphical Summaries**

# %%
sns.kdeplot(data=df, x="entertainment_spend_est", hue="county", multiple="stack");

# %%
sns.kdeplot(data=df, x="entertainment_spend_est", hue="own_rent", multiple="stack");

# %%
# sns.pairplot(data=df, hue="county"); #takes time to run

# %%
# sns.swarmplot(data=df, x="own_rent", y = "entertainment_spend_est", hue="county"); # takes time to run

# %% [markdown]
# **Correlation**

# %%
corr = df.corr().round(3)

plt.figure(figsize= (15,8))
sns.heatmap(corr, annot= True);

# %% [markdown]
# ##  <font color= darkred> Data Prep for Modeling </font>

# %% [markdown]
# ### Scaling Data
#
# * [Why Scaling is important for Clustering](https://stats.stackexchange.com/questions/89809/is-it-important-to-scale-data-before-clustering)

# %%
# df.head()

# %% [markdown]
# **Selecting only the numerical columns**

# %%
df_numerical = df.select_dtypes(['int', 'float'])
df_numerical.head(2)
# Out:
#    total_ppl  square_foot  household_income  number_pets  \
# 0          3         3309             80464            1
# 1          3         3814             47696            2
#
#    entertainment_spend_est  travel_spend_est  under_12
# 0                     2535              2842         1
# 1                     2913              3938         1

# %% [markdown]
# **Standardizing**

# %%
from sklearn.preprocessing import StandardScaler

# intiate 
scaler = StandardScaler()

# fit and transform 
df_numerical_scaled = scaler.fit_transform(df_numerical)

# %%
type(df_numerical_scaled)
# Out:
# numpy.ndarray

# %% [markdown]
# **Converting to Pandas and Visualizing**

# %%
df_numerical_scaled = pd.DataFrame(df_numerical_scaled, columns = df_numerical.columns)

# %%
df_numerical.plot(kind = 'kde', subplots = True);

# %%
df_numerical_scaled.plot(kind = 'kde', subplots = True);

# %% [markdown]
# **Replacing the original values with scaled values**

# %%
num_cols = df_numerical.columns.tolist()

# %%
df_orig = df.copy()

# %%
df.loc[:, num_cols] = df_numerical_scaled[num_cols]

# %%
df.head()
# Out:
#    total_ppl own_rent  square_foot  household_income  number_pets      county  \
# 0  -0.145886      own     0.232960          0.421607    -0.644446        York
# 1  -0.145886      own     0.851909         -1.325289     0.621159        York
# 2  -0.145886     rent    -0.645826          1.903227     0.621159  Cumberland
# 3  -1.267513      own    -0.601703         -0.239450    -0.644446  Cumberland
# 4  -0.145886     rent    -0.829672         -0.520825     0.621159   Sagadahoc
#
#    entertainment_spend_est  travel_spend_est  under_12 LL_passholder
# 0                -0.152014         -1.190688 -1.047109            No
# 1                 0.341153          0.636601 -1.047109            No
# 2                -0.868282          0.218125  0.318923            No
# 3                -0.191155         -1.217364 -1.047109            No
# 4                 1.160490         -3.688205  0.318923            No

# %% [markdown]
# ### Convert categorical value to numerical

# %%
df = pd.get_dummies(df, drop_first = True)

# %%
df.head(2)
# Out:
#    total_ppl  square_foot  household_income  number_pets  \
# 0  -0.145886     0.232960          0.421607    -0.644446
# 1  -0.145886     0.851909         -1.325289     0.621159
#
#    entertainment_spend_est  travel_spend_est  under_12  own_rent_rent  \
# 0                -0.152014         -1.190688 -1.047109              0
# 1                 0.341153          0.636601 -1.047109              0
#
#    county_Sagadahoc  county_York  LL_passholder_Yes
# 0                 0            1                  0
# 1                 0            1                  0

# %% [markdown]
# ## <font color= darkred> Model building </font> 💥⚡

# %% [markdown]
# ### Clustering using [KMeans](https://scikit-learn.org/stable/modules/generated/sklearn.cluster.KMeans.html)

# %%
from sklearn.cluster import KMeans

# %% [markdown]
# ### Optimal Clusters using Elbow Method

# %%
sse = {}

for k in range(2, 12):
    kmeans = KMeans(n_clusters= k, random_state = 0)
    kmeans.fit(df)
    sse[k] = kmeans.inertia_
    
#Viz    
plt.figure(figsize=(16,8))
plt.title('The Elbow Method for optimal k')
plt.xlabel('k')
plt.ylabel('SSE')
sns.pointplot(x=list(sse.keys()), y=list(sse.values()));

# %% [markdown]
# **Understand the change in Elbow Methods**

# %%
interia_df = pd.DataFrame(sse, index = range(0, len(sse)))
interia_df = interia_df.drop_duplicates().T
interia_df['pct_change'] = interia_df.pct_change().round(4).multiply(-100)
interia_df = interia_df.reset_index()
interia_df
# Out:
#    index              0  pct_change
# 0      2  100361.820228         NaN
# 1      3   92497.406894        7.84
# 2      4   87113.872506        5.82
# 3      5   83430.557557        4.23
# 4      6   79973.591814        4.14
# 5      7   77214.974768        3.45
# 6      8   74556.388356        3.44
# 7      9   72283.143401        3.05
# 8     10   70193.309446        2.89
# 9     11   68631.007490        2.23

# %%
plt.figure(figsize=(16,8))

# plot the chart
sns.pointplot(interia_df['index'], y = interia_df['pct_change'])

# format chart
plt.title('Percentage change in inertia across k')
plt.xlabel('k')
plt.ylabel('Percentage change');

# %%
# intiate the model 
kmean = KMeans(random_state=0, n_clusters = 5)

# fit the model 
kmean.fit(df)
# Out:
# KMeans(n_clusters=5, random_state=0)

# %%
kmean.labels_
len(kmean.labels_)
# Out:
# 15000

# %%
df_orig['cluster'] = kmean.labels_

# %%
df_orig.head(2)
# Out:
#    total_ppl own_rent  square_foot  household_income  number_pets county  \
# 0          3      own         3309             80464            1   York
# 1          3      own         3814             47696            2   York
#
#    entertainment_spend_est  travel_spend_est  under_12 LL_passholder  cluster
# 0                     2535              2842         1            No        3
# 1                     2913              3938         1            No        1

# %% [markdown]
# ## Cluster Level Analysis

# %%
grouped = df_orig.groupby(['cluster'])

grouped.agg({
'total_ppl' : 'mean', 
'square_foot': 'mean',
'household_income' : 'mean',
'number_pets' : 'mean',
'entertainment_spend_est' : 'mean',
'travel_spend_est' : ['mean','count'],
'under_12' : 'mean'}).round(2)
# Out:
#         total_ppl square_foot household_income number_pets  \
#              mean        mean             mean        mean
# cluster
# 0            2.81     2623.04         70051.28        2.27
# 1            3.32     3988.93         68918.10        1.51
# 2            4.26     2746.49         73767.24        1.49
# 3            2.79     2601.36         69663.25        0.77
# 4            2.66     3735.89         82910.00        1.48
#
#         entertainment_spend_est travel_spend_est       under_12
#                            mean             mean count     mean
# cluster
# 0                       2654.46          3314.59  3417     1.60
# 1                       3054.80          3934.48  3172     2.06
# 2                       2567.18          3395.31  2503     2.38
# 3                       2653.80          3288.70  3330     1.58
# 4                       2230.34          3912.56  2578     1.27

# %%
sns.barplot(data = df_orig, x = 'cluster', y = 'entertainment_spend_est', ci = None);

# %%
sns.barplot(data = df_orig, x = 'cluster', y = 'entertainment_spend_est', ci = None);

# %%
sns.scatterplot(data = df_orig, x = 'travel_spend_est', y = 'entertainment_spend_est', hue = 'cluster', 
               size="cluster", palette="deep", style="cluster");

# %%
g = sns.FacetGrid(df_orig, col="cluster")
g

# %%
g = sns.FacetGrid(df_orig, row="cluster",  hue = 'cluster',palette = "deep")

g.map(sns.scatterplot, 'travel_spend_est', 'entertainment_spend_est')

# %% [markdown]
# <div class="alert alert-block alert-success">
#
# # Reference material 📚
#
#
# * [Python Data Science Handbook](https://jakevdp.github.io/PythonDataScienceHandbook/): good book for hands on practice and codes.
# * [ISLR](https://www.statlearning.com/)- good coverage of the theory
#
# * [Kmeans Categorical](https://towardsdatascience.com/clustering-on-numerical-and-categorical-features-6e0ebcf1cbad)
# * [Clustering Mixed Data](https://www.tomasbeuzen.com/post/clustering-mixed-data/)
#
# </div>
