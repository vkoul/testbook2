# %% [markdown]
# <div class="alert alert-block alert-success">
#
# # Imperial Business Analytics OH: WK9- Correlation & Regression
#
#  👨‍🏫 **Vikesh K**
#  📅 **[10-Jan-2023]** ⏰ **7pm UTC**
#  **Office Hour # 08**
#
#
# </div>

# %% [markdown]
#  💡  <span style='font-family:Georgia'>
#     <font color= darkred> ***Your deepest moments of happiness don’t come from doing easy things; they come from realizing your potential and overcoming your own limiting beliefs about yourself.― Scott H. Young***
#     </font> 💡

# %% [markdown]
# <div class="alert alert-block alert-success">
#
# # OH Agenda 📝
#
# We will cover:
#
# * ML Overview
# * Retail Case Study
#     * EDA with respect to model building
#     * Data Prep
#     * Building a Linear regression model
#     * Solving the business scenario
#
#
#  </div>

# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Imperial-Business-Analytics-OH:-WK9--Correlation-&amp;-Regression" data-toc-modified-id="Imperial-Business-Analytics-OH:-WK9--Correlation-&amp;-Regression-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Imperial Business Analytics OH: WK9- Correlation &amp; Regression</a></span></li><li><span><a href="#OH-Agenda-📝" data-toc-modified-id="OH-Agenda-📝-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>OH Agenda 📝</a></span></li><li><span><a href="#-ML-Overview-▶️-" data-toc-modified-id="-ML-Overview-▶️--3"><span class="toc-item-num">3&nbsp;&nbsp;</span><font color="darkblue"> ML Overview ▶️ </font></a></span><ul class="toc-item"><li><span><a href="#ML-Classification" data-toc-modified-id="ML-Classification-3.1"><span class="toc-item-num">3.1&nbsp;&nbsp;</span>ML Classification</a></span></li><li><span><a href="#ML-techniques-overview" data-toc-modified-id="ML-techniques-overview-3.2"><span class="toc-item-num">3.2&nbsp;&nbsp;</span>ML techniques overview</a></span></li><li><span><a href="#Target-and-features" data-toc-modified-id="Target-and-features-3.3"><span class="toc-item-num">3.3&nbsp;&nbsp;</span>Target and features</a></span></li><li><span><a href="#Train-and-test-split" data-toc-modified-id="Train-and-test-split-3.4"><span class="toc-item-num">3.4&nbsp;&nbsp;</span>Train and test split</a></span></li><li><span><a href="#Linear-regression" data-toc-modified-id="Linear-regression-3.5"><span class="toc-item-num">3.5&nbsp;&nbsp;</span>Linear regression</a></span></li><li><span><a href="#sklearn-steps" data-toc-modified-id="sklearn-steps-3.6"><span class="toc-item-num">3.6&nbsp;&nbsp;</span><code>sklearn</code> steps</a></span></li></ul></li><li><span><a href="#Case-Study-📓:-Cloth-Retailer" data-toc-modified-id="Case-Study-📓:-Cloth-Retailer-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Case Study 📓: Cloth Retailer</a></span><ul class="toc-item"><li><span><a href="#-Import-modules-and-data-" data-toc-modified-id="-Import-modules-and-data--4.1"><span class="toc-item-num">4.1&nbsp;&nbsp;</span><font color="darkred"> Import modules and data </font></a></span></li><li><span><a href="#-Data-Inspection🔍📊" data-toc-modified-id="-Data-Inspection🔍📊-4.2"><span class="toc-item-num">4.2&nbsp;&nbsp;</span><font color="darkred"> Data Inspection</font>🔍📊</a></span><ul class="toc-item"><li><span><a href="#-Numerical-inspection-and-summaries-" data-toc-modified-id="-Numerical-inspection-and-summaries--4.2.1"><span class="toc-item-num">4.2.1&nbsp;&nbsp;</span><font color="darkred"> Numerical inspection and summaries </font></a></span></li></ul></li><li><span><a href="#-EDA-" data-toc-modified-id="-EDA--4.3"><span class="toc-item-num">4.3&nbsp;&nbsp;</span><font color="darkred"> EDA </font></a></span><ul class="toc-item"><li><span><a href="#Univariate-Analysis" data-toc-modified-id="Univariate-Analysis-4.3.1"><span class="toc-item-num">4.3.1&nbsp;&nbsp;</span>Univariate Analysis</a></span></li><li><span><a href="#Bivariate-Analysis" data-toc-modified-id="Bivariate-Analysis-4.3.2"><span class="toc-item-num">4.3.2&nbsp;&nbsp;</span>Bivariate Analysis</a></span></li></ul></li><li><span><a href="#-Data-Prep-for-Linear-Regression-" data-toc-modified-id="-Data-Prep-for-Linear-Regression--4.4"><span class="toc-item-num">4.4&nbsp;&nbsp;</span><font color="darkred"> Data Prep for Linear Regression </font></a></span><ul class="toc-item"><li><span><a href="#Standardization" data-toc-modified-id="Standardization-4.4.1"><span class="toc-item-num">4.4.1&nbsp;&nbsp;</span>Standardization</a></span></li></ul></li><li><span><a href="#-Model-building--💥⚡" data-toc-modified-id="-Model-building--💥⚡-4.5"><span class="toc-item-num">4.5&nbsp;&nbsp;</span><font color="darkred"> Model building </font> 💥⚡</a></span><ul class="toc-item"><li><span><a href="#-Train-Data-predictions-" data-toc-modified-id="-Train-Data-predictions--4.5.1"><span class="toc-item-num">4.5.1&nbsp;&nbsp;</span><font color="darkred"> Train Data predictions </font></a></span></li><li><span><a href="#-Test-Data-predictions-" data-toc-modified-id="-Test-Data-predictions--4.5.2"><span class="toc-item-num">4.5.2&nbsp;&nbsp;</span><font color="darkred"> Test Data predictions </font></a></span></li><li><span><a href="#-Model-Coeficeients-" data-toc-modified-id="-Model-Coeficeients--4.5.3"><span class="toc-item-num">4.5.3&nbsp;&nbsp;</span><font color="darkred"> Model Coeficeients </font></a></span></li></ul></li><li><span><a href="#-Decision-making-💲" data-toc-modified-id="-Decision-making-💲-4.6"><span class="toc-item-num">4.6&nbsp;&nbsp;</span><font color="red"> Decision making </font>💲</a></span></li><li><span><a href="#Export-the-model" data-toc-modified-id="Export-the-model-4.7"><span class="toc-item-num">4.7&nbsp;&nbsp;</span>Export the model</a></span></li><li><span><a href="#Further-Practise-🤿" data-toc-modified-id="Further-Practise-🤿-4.8"><span class="toc-item-num">4.8&nbsp;&nbsp;</span>Further Practise 🤿</a></span></li></ul></li><li><span><a href="#Reference-material-📚" data-toc-modified-id="Reference-material-📚-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>Reference material 📚</a></span></li></ul></div>

# %% [markdown]
# # <font color= darkblue> ML Overview ▶️ </font>

# %% [markdown]
# ## ML Classification

# %% [markdown]
# ![supervised_and_unsupervised.jpg](attachment:supervised_and_unsupervised.jpg)

# %% [markdown]
# <div class="alert alert-block alert-danger">
#
# ## ML techniques overview
#
# The techniques covered in the course
#
#
# | Analytic Task | Application       | ML Algos                                                        | Learning Type |
# |---------------|-------------------|-----------------------------------------------------------------|---------------|
# | Prediction    | Classification    | Decision trees, Support Vector Machines, kNN                    | Supervised    |
# | Prediction    | Regression        | Linear regression, Regression trees, SVM, kNN,        | Supervised    |
# | Segmentation  | Clustering        | K-means, Hierarchical Clustering                                | Unsupervised  |

# %% [markdown]
# <div class="alert alert-block alert-danger">
#
# ## Target and features

# %% [markdown]
# ![mldiagram.png](attachment:mldiagram.png)

# %% [markdown]
# <div class="alert alert-block alert-danger">
#
# ## Train and test split

# %% [markdown]
# ![train_test_split.png](attachment:train_test_split.png)

# %% [markdown]
# <div class="alert alert-block alert-danger">
#
# ## Linear regression
# * Linear regression attempts to model the relationship between two variables by fitting a linear equation to observed data. * One variable is considered to be an explanatory variable, and the other is considered to be a dependent variable. For example, a modeler might want to relate the weights of individuals to their heights using a linear regression model
#
# * A linear regression line has an equation of the form $Y = a + bX$, where X is the explanatory variable and Y is the dependent variable. The slope of the line is b, and a is the intercept (the value of y when x = 0).
#
#
#
# ## `sklearn` steps
#
# ML in `sklearn` steps
#
# Scikit-learn is the tool for simple machine learning pipelines.
#
# It's a single library that unites a whole bunch of models under the common interface:
#
# * Create: `model = sklearn.ModelNameHere(parameters_if_any)`
# * Train: `model.fit(X,y)`
# * Predict: `model.predict(X_test)`

# %% [markdown]
# <div class="alert alert-block alert-success">
#
# # Case Study 📓: Cloth Retailer
#
# **[Case Study Details](https://docs.google.com/document/d/1BK9u8xFA9g8VMVZBLP1kCl6AqRp-Ue91y8p4mrWaKUo/edit?usp=sharing
# )**
#
# **Can you help the Sales manager to decide amongst the four scenarios?**
#
#
# **You would need to use linear regression to establish the relationship between Price, advertisement, promotion, and units sold.
# Essentially, you need to estimate the coefficient values of the equation that will establish the relationship between independent variables and dependent variables (unit sales)**
#
#
# ![image-2.png](attachment:image-2.png)
#
#
# </div>

# %% [markdown]
# ![scenarios.png](attachment:scenarios.png)

# %% [markdown]
# ##  <font color= darkred> Import modules and data </font>

# %%
# data manipulation
import pandas as pd
import numpy as np

# data viz
import matplotlib.pyplot as plt
import seaborn as sns
# plt.style.use("fivethirtyeight") # styling the charts

# data prep
from sklearn.model_selection import train_test_split

# ML algos
from sklearn.linear_model import LinearRegression

# metrics 
from sklearn.metrics import mean_squared_error, mean_absolute_error

# %%
# loading the data 
df = pd.read_csv("https://raw.githubusercontent.com/vkoul/data/main/misc/tshirt_sales.csv")
scenario = pd.read_csv("https://raw.githubusercontent.com/vkoul/data/main/misc/business_scenario.csv")

# %%
# scenario.columns
# df.columns

# %% [markdown]
# ##  <font color= darkred> Data Inspection</font>🔍📊

# %% [markdown]
# ### <font color= darkred> Numerical inspection and summaries </font>

# %% [markdown]
# **Data Inspect**

# %%
df.info()
display(df.head())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 24 entries, 0 to 23
# Data columns (total 6 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Year          24 non-null     int64
#  1   Month         24 non-null     int64
#  2   units_sold    24 non-null     int64
#  3   dollar_price  24 non-null     float64
#  4   advertisment  24 non-null     float64
#  5   promotions    24 non-null     float64
# dtypes: float64(3), int64(3)
# memory usage: 1.2 KB
#    Year  Month  units_sold  dollar_price  advertisment  promotions
# 0  2019      1       73959          8.75         50.04       61.13
# 1  2019      2       71544          8.99         50.74       60.19
# 2  2019      3       78587          7.50         50.14       59.16
# 3  2019      4       80364          7.25         50.27       60.38
# 4  2019      5       78771          7.40         51.25       59.71

# %% [markdown]
# **Missing values check**

# %%
# missing values
df.isna().sum()
# Out:
# Year            0
# Month           0
# units_sold      0
# dollar_price    0
# advertisment    0
# promotions      0
# dtype: int64

# %% [markdown]
# **Select only the key columns**

# %%
key_columns = ['units_sold', 'dollar_price', 'advertisment','promotions']

# %%
key_columns
# Out:
# ['units_sold', 'dollar_price', 'advertisment', 'promotions']

# %% [markdown]
# **Numerical summary of the key columns**

# %%
df[key_columns].describe().round(2)
# Out:
#        units_sold  dollar_price  advertisment  promotions
# count       24.00         24.00         24.00       24.00
# mean     74258.29          8.13         50.15       59.88
# std       3164.39          0.51          1.28        0.68
# min      69003.00          7.25         48.00       58.00
# 25%      71959.50          7.90         49.40       59.64
# 50%      74103.00          8.15         50.12       59.90
# 75%      76354.50          8.43         50.77       60.24
# max      80364.00          8.99         54.00       61.13

# %% [markdown]
# ##   <font color= darkred> EDA </font>

# %% [markdown]
# ### Univariate Analysis

# %% [markdown]
# `pandas.DataFrame.hist` function calls matplotlib.pyplot.hist(), on each series in the DataFrame, resulting in one histogram per column.

# %%
# plot the histograms of the key columns
df[key_columns].hist(figsize = (10, 8), grid = False, color= 'darkred');

# %%
# df['units_sold'].plot.kde(figsize = (10, 5));

# %%
df[key_columns].plot.line(figsize = (10, 10), subplots=True, marker = 's');

# %% [markdown]
# ### Bivariate Analysis

# %%
# sns.pairplot(df[key_columns]);
# sns.pairplot(df[key_columns], kind ='reg');
sns.pairplot(df[key_columns], diag_kind = 'kde');

# %% [markdown]
# **Correlation between values**

# %%
corr = df[key_columns].corr().round(3)

plt.figure(figsize = (10,8))

# basic one
# sns.heatmap(corr, annot = True);

# sns.heatmap(corr, annot = True).set_title('Correlation Heatmap', fontdict={'fontsize':13}, pad=12); # ADD TITLE

# sns.heatmap(corr, annot = True, cmap='BrBG'); # DIVERGING COLOR SCHEME

# tri_corr = np.triu(np.ones_like(corr, dtype=np.bool)) # returns upper triangle of an array.
# sns.heatmap(corr, annot = True, mask = tri_corr); # TRIANGLE VIEW

# %% [markdown]
# **Visualise Linear relationship between variables**

# %%
# sns.lmplot(x = "dollar_price", y = "units_sold", data = df,  order = 1, markers= ['v'], ci = False);
# sns.lmplot(x = "advertisment", y = "units_sold", data = df, ci = False, order = 1, markers= ['o']);
# sns.lmplot(x = "promotions", y = "units_sold", data = df, ci = False, order = 1, markers= ['x']);

# %%
# # Plotting the linecharts

# # plot size
# plt.figure(figsize = (10,5))

# # line chart
# df["units_sold"].plot(kind = "line", label = "actual_units", marker = "o");


# # labels
# plt.ylabel("Units sold")
# plt.title("Units sold over the period")

# # show
# plt.show();

# %% [markdown]
# ##  <font color= darkred> Data Prep for Linear Regression </font>

# %% [markdown]
# ![featuresMatrixTargetVector.png](attachment:featuresMatrixTargetVector.png)

# %% [markdown]
# <div class="alert alert-block alert-danger">
#
# **Specifiying a particular `random_state` will ensure that our data split happens in the same manner**

# %%
# splitting the data 

X = df[key_columns].drop(columns = "units_sold")
y = df["units_sold"]


# # doing train test split
x_train, x_test, y_train, y_test = train_test_split(X, y, test_size = 0.2, random_state = 32)

# %%
print("x_train: ", x_train.shape)
print("x_test: ", x_test.shape)

print("\n")

print("y_train: ", y_train.shape)
print("y_test: ", y_test.shape)

display(x_train.head())
display(y_train.head())
# Out:
# x_train:  (19, 3)
# x_test:  (5, 3)
#
#
# y_train:  (19,)
# y_test:  (5,)
#     dollar_price  advertisment  promotions
# 6           8.40         50.87       60.14
# 15          8.30         49.46       60.06
# 0           8.75         50.04       61.13
# 13          7.40         49.24       60.40
# 2           7.50         50.14       59.16
# 6     74885
# 15    74247
# 0     73959
# 13    78542
# 2     78587
# Name: units_sold, dtype: int64

# %% [markdown]
# ### Standardization

# %%
x_train.plot(kind = 'kde');

# %%
x_train.plot(kind = 'kde', subplots= True);

# %%
from sklearn. preprocessing import StandardScaler 

# fit the module on your train dataset so it learns the pattern. The scaler gets loaded with the necessary value
scaler = StandardScaler().fit(x_train)

# use the scaler's transform feature now to convert the new dataset
x_train_scaled = scaler.transform(x_train)

# %%
x_train_scaled = pd.DataFrame(x_train_scaled, columns = x_train.columns)

# %%
x_train_scaled.plot(kind = 'kde');

# %%
x_train_scaled.plot(kind = 'kde', subplots= True);

# %% [markdown]
# ## <font color= darkred> Model building </font> 💥⚡

# %%
y.mean()
# Out:
# 74258.29166666667

# %% [markdown]
# **Normal data**

# %%
# call the model 
model = LinearRegression()

# fit the model
model.fit(x_train, y_train)

# # calculate the score
print("R^2: {:.2f}".format(model.score(x_train, y_train)))

# make the predictions on train data
predictions = np.round(model.predict(x_train),1)

# accuracy metrics
print("RMSE: {:.2f}".format(mean_squared_error(y_train, predictions, squared = False)))
print("MAE: {:.2f}".format(mean_absolute_error(y_train, predictions))) # the 2f means that its is for 2 decimal
# Out:
# R^2: 0.87
# RMSE: 1144.65
# MAE: 809.04

# %% [markdown]
# **Scaled Data**

# %%
# call the model 
model2 = LinearRegression()

# fit the model
model2.fit(x_train_scaled, y_train)

# # calculate the score
print("R^2: {:.2f}".format(model2.score(x_train_scaled, y_train)))

# make the predictions on train data
predictions = np.round(model2.predict(x_train_scaled),1)

# accuracy metrics
print("RMSE: {:.2f}".format(mean_squared_error(y_train, predictions, squared = False)))
print("MAE: {:.2f}".format(mean_absolute_error(y_train, predictions))) # the 2f means that its is for 2 decimal
# Out:
# R^2: 0.87
# RMSE: 1144.65
# MAE: 809.04

# %% [markdown]
# ### <font color= darkred> Train Data predictions </font>

# %%
# combine the actual data and predictions
output = pd.DataFrame({"actual": y_train, 
                       "predictions": predictions})

# sort the index
output = output.sort_index()

# new output
output.head()
# Out:
#    actual  predictions
# 0   73959      73447.8
# 1   71544      70763.2
# 2   78587      76394.2
# 3   80364      80170.6
# 4   78771      78657.9

# %%
# add prediction back to the data and visualise

#plot size
plt.figure(figsize = (10,5))

# line chart
plt.plot(output["actual"], marker = "o", label = "actual")
plt.plot(output["predictions"], marker = "o", label = "predictions")

# labels
plt.ylabel("Units sold")
plt.title("Units sold over the period: Train Data")

# show labels
plt.legend()

# show
plt.show();

# %% [markdown]
# ###  <font color= darkred> Test Data predictions </font>

# %%
# predicting for test data 

test_predictions = np.round(model.predict(x_test),1)

# calculate the score
print("R^2 of test: {:.2f}".format(model.score(x_test, y_test)))


# accuracy metrics
print("RMSE of test: {:.2f}".format(mean_squared_error(y_test, test_predictions, squared = False)))
print("MAE of test: {:.2f}".format(mean_absolute_error(y_test, test_predictions))) # the 2f means that its is for 2 decimal
# Out:
# R^2 of test: 0.74
# RMSE of test: 1330.18
# MAE of test: 1033.68

# %%
# creating a df with test data and predictions

test_output = pd.DataFrame({"actual": y_test, 
                           "test_predictions": test_predictions})

# sorting index
test_output = test_output.sort_index()
test_output.head()
# Out:
#     actual  test_predictions
# 8    76659           78027.3
# 14   72543           75067.5
# 16   76253           76676.5
# 17   72582           71984.0
# 20   69701           69446.9

# %%
# add prediction back to the data and visualise

# plot size
plt.figure(figsize = (10,5))

# line chart
plt.plot(test_output["actual"], marker = "o", label = "actual")
plt.plot(test_output["test_predictions"], marker = "o", label = "predictions")

# labels
plt.ylabel("Units sold")
plt.title("Units sold over the period: Test Data")

# show labels
plt.legend()

# show
plt.show();

# %% [markdown]
# ###  <font color= darkred> Model Coeficeients </font>

# %% [markdown]
# A linear regression model is of the type: $y = \beta_0 + \beta_1x_1 + \beta_2x_2 + \beta_3x_2 $ ; where $\beta_0$ is the intercept and other $\beta$ are the coefficient of the columns.
#
# The linear regression model will help us find the value of these $\beta$

# %%
# printing the results after rounding off
print("The intercept is:", np.round(model.intercept_,1))
print("The co-efficients are:", np.round(model.coef_,1))
# Out:
# The intercept is: -27846.9
# The co-efficients are: [-5357.    598.5  1933.9]

# %% [markdown]
# Putting the above information in a data-frame which is readable

# %%
coeffs = pd.DataFrame(np.round(model.coef_,1), x_train.columns, columns = ["Coefficient"])
display(coeffs)
coeffs.plot(kind = "bar");
# Out:
#               Coefficient
# dollar_price      -5357.0
# advertisment        598.5
# promotions         1933.9

# %% [markdown]
# Hence our equation will be:
#
#  **$ units sold = -27846.9 + -5357.0  \cdot dollar price + 598.5 \cdot advertisment +  1933.9 \cdot promotions$**

# %% [markdown]
# ##  <font color= red> Decision making </font>💲

# %%
scenario
scenario[['dollar_price', 'advertisment','promotions']]
# Out:
#    dollar_price  advertisment  promotions
# 0            10            50          61
# 1             8            45          55
# 2             6            40          50
# 3            10            40          50

# %%
# making the predictions
projections = np.round(model.predict(scenario[['dollar_price', 'advertisment','promotions']]),0)
projections
# Out:
# array([66476., 62594., 60646., 39218.])

# %%
# adding the predictions to the data 
scenario["projections"] = projections
scenario.style.set_properties(**{'background-color': 'darkred',
                                   'color': 'white',
                                   'border-color': 'white'}, subset= ['projections'])
# Out:
# <style type="text/css">
# #T_47234_row0_col5, #T_47234_row1_col5, #T_47234_row2_col5, #T_47234_row3_col5 {
#   background-color: darkred;
#   color: white;
#   border-color: white;
# }
# </style>
# <table id="T_47234">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_47234_level0_col0" class="col_heading level0 col0" >business_context</th>
#       <th id="T_47234_level0_col1" class="col_heading level0 col1" >scenario</th>
#       <th id="T_47234_level0_col2" class="col_heading level0 col2" >dollar_price</th>
#       <th id="T_47234_level0_col3" class="col_heading level0 col3" >advertisment</th>
#       <th id="T_47234_level0_col4" class="col_heading level0 col4" >promotions</th>
#       <th id="T_47234_level0_col5" class="col_heading level0 col5" >projections</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_47234_level0_row0" class="row_heading level0 row0" >0</th>
# ...

# %%
# Filter out the final scenario
scenario[scenario["projections"] == scenario["projections"].max()]
# Out:
#              business_context    scenario  dollar_price  advertisment  \
# 0  High price; high marketing  Scenario 1            10            50
#
#    promotions  projections
# 0          61      66476.0

# %% [markdown]
# Another way to highlight in Pandas

# %%
scenario.style.apply(lambda x: ['background:darkorange' if x in "Scenario 1" else None for x in scenario.scenario])
# Out:
# <style type="text/css">
# #T_3bd92_row0_col0, #T_3bd92_row0_col1, #T_3bd92_row0_col2, #T_3bd92_row0_col3, #T_3bd92_row0_col4, #T_3bd92_row0_col5 {
#   background: darkorange;
# }
# </style>
# <table id="T_3bd92">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_3bd92_level0_col0" class="col_heading level0 col0" >business_context</th>
#       <th id="T_3bd92_level0_col1" class="col_heading level0 col1" >scenario</th>
#       <th id="T_3bd92_level0_col2" class="col_heading level0 col2" >dollar_price</th>
#       <th id="T_3bd92_level0_col3" class="col_heading level0 col3" >advertisment</th>
#       <th id="T_3bd92_level0_col4" class="col_heading level0 col4" >promotions</th>
#       <th id="T_3bd92_level0_col5" class="col_heading level0 col5" >projections</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_3bd92_level0_row0" class="row_heading level0 row0" >0</th>
# ...

# %% [markdown]
# ## Export the model

# %%
import pickle

# %%
filename = 'lm_model_prediction.sav' # name of the file 
pickle.dump(model, open(filename, 'wb')) # exporting the file

# %%
pred = 203224.34

# %%
print(f"Predicted units to sell: {pred:,.0f} ")
# Out:
# Predicted units to sell: 203,224

# %% [markdown]
# <div class="alert alert-block alert-danger">
#
# ## Further Practise 🤿
#
# * Build a [KNeighborsRegressor](https://scikit-learn.org/stable/modules/generated/sklearn.neighbors.KNeighborsRegressor.html) model with the same steps as above
# * Standardize the values using a StandardScaler() and see if it makes an impact on the predictions
# * Remember the Spotify dataset covered in earlier OH. Can you build a model for predicting popularity using ML.

# %% [markdown]
# <div class="alert alert-block alert-success">
#
# # Reference material 📚
#
# **Linear Regression Theory**📚
#
# * [Linear Regression Overview](http://www.stat.yale.edu/Courses/1997-98/101/linreg.htm)📓
# * [An Introduction to Linear Regression Analysis](https://www.youtube.com/watch?v=zPG4NjIkCjc&t=67s)📺
#
# **Linear Regression Practical** 🙇
#
#
# * [Regression models in `scikit-learn`](https://scikit-learn.org/stable/supervised_learning.html)
#
# * [Linear Regression in `scikit-learn`](https://scikit-learn.org/stable/modules/generated/sklearn.linear_model.LinearRegression.html#sklearn.linear_model.LinearRegression.score)
#
# * [Explanation of linear regresion in python](https://realpython.com/linear-regression-in-python/)
#
# * [Intro to ML in scikit-learn](https://scikit-learn.org/stable/tutorial/basic/tutorial.html)
#
# * [ML Algos overview](https://scikit-learn.org/stable/tutorial/statistical_inference/supervised_learning.html)
#
# **Data Vis** 📊
#
# * [Visualising Regression Models](https://seaborn.pydata.org/tutorial/regression.html)
# * [Visualizing Data with Pairs Plots in Python](https://towardsdatascience.com/visualizing-data-with-pair-plots-in-python-f228cf529166)
# * [How to Create a Seaborn Correlation Heatmap in Python?](https://medium.com/@szabo.bibor/how-to-create-a-seaborn-correlation-heatmap-in-python-834c0686b88e)
#
# </div>
