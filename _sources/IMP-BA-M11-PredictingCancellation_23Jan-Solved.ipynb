# %% [markdown]
# <div class="alert alert-block alert-success">
#
#
# # Imperial Business Analytics OH: WK11- Classification and Regression Trees
#
#  👨‍🏫 **Vikesh K**
#  📅 **[23-Jan-2023]** ⏰ **7pm UTC**
#  #️⃣ **Office Hour # 10**
#
#
# </div>

# %% [markdown]
# <div class="alert alert-block alert-danger">
#
# # OH Agenda 📝
#
# We will cover:
#
# * Cancellation Prediction
#     * EDA with respect to model building
#     * Data Prep
#     * Model Building
#     * Business Insights
#
#
#
#  </div>

# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Imperial-Business-Analytics-OH:-WK11--Classification-and-Regression-Trees" data-toc-modified-id="Imperial-Business-Analytics-OH:-WK11--Classification-and-Regression-Trees-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Imperial Business Analytics OH: WK11- Classification and Regression Trees</a></span></li><li><span><a href="#OH-Agenda-📝" data-toc-modified-id="OH-Agenda-📝-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>OH Agenda 📝</a></span></li><li><span><a href="#Case-Study-📓:-Predict-Cancellation" data-toc-modified-id="Case-Study-📓:-Predict-Cancellation-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Case Study 📓: Predict Cancellation</a></span><ul class="toc-item"><li><span><a href="#-Import-modules-and-data-" data-toc-modified-id="-Import-modules-and-data--3.1"><span class="toc-item-num">3.1&nbsp;&nbsp;</span><font color="darkred"> Import modules and data </font></a></span></li><li><span><a href="#-Data-Inspection🔍📊" data-toc-modified-id="-Data-Inspection🔍📊-3.2"><span class="toc-item-num">3.2&nbsp;&nbsp;</span><font color="darkred"> Data Inspection</font>🔍📊</a></span><ul class="toc-item"><li><span><a href="#-Numerical-inspection-and-summaries-" data-toc-modified-id="-Numerical-inspection-and-summaries--3.2.1"><span class="toc-item-num">3.2.1&nbsp;&nbsp;</span><font color="darkred"> Numerical inspection and summaries </font></a></span></li></ul></li><li><span><a href="#-EDA-" data-toc-modified-id="-EDA--3.3"><span class="toc-item-num">3.3&nbsp;&nbsp;</span><font color="darkred"> EDA </font></a></span><ul class="toc-item"><li><span><a href="#Univariate-Analysis" data-toc-modified-id="Univariate-Analysis-3.3.1"><span class="toc-item-num">3.3.1&nbsp;&nbsp;</span>Univariate Analysis</a></span></li><li><span><a href="#Bivariate-Analysis" data-toc-modified-id="Bivariate-Analysis-3.3.2"><span class="toc-item-num">3.3.2&nbsp;&nbsp;</span>Bivariate Analysis</a></span></li></ul></li><li><span><a href="#-Data-Prep-for-Modeling-" data-toc-modified-id="-Data-Prep-for-Modeling--3.4"><span class="toc-item-num">3.4&nbsp;&nbsp;</span><font color="darkred"> Data Prep for Modeling </font></a></span><ul class="toc-item"><li><span><a href="#Convert-categorical-value-to-numerical" data-toc-modified-id="Convert-categorical-value-to-numerical-3.4.1"><span class="toc-item-num">3.4.1&nbsp;&nbsp;</span>Convert categorical value to numerical</a></span></li><li><span><a href="#Train-Test-Split" data-toc-modified-id="Train-Test-Split-3.4.2"><span class="toc-item-num">3.4.2&nbsp;&nbsp;</span>Train-Test Split</a></span></li><li><span><a href="#Scaling" data-toc-modified-id="Scaling-3.4.3"><span class="toc-item-num">3.4.3&nbsp;&nbsp;</span>Scaling</a></span></li></ul></li><li><span><a href="#-Model-building--💥⚡" data-toc-modified-id="-Model-building--💥⚡-3.5"><span class="toc-item-num">3.5&nbsp;&nbsp;</span><font color="darkred"> Model building </font> 💥⚡</a></span><ul class="toc-item"><li><span><a href="#Dummy-classifier-model-using-DummyClassifier" data-toc-modified-id="Dummy-classifier-model-using-DummyClassifier-3.5.1"><span class="toc-item-num">3.5.1&nbsp;&nbsp;</span>Dummy classifier model using <a href="https://scikit-learn.org/stable/modules/generated/sklearn.dummy.DummyClassifier.html" rel="nofollow" target="_blank">DummyClassifier</a></a></span></li><li><span><a href="#Logistic-Regression-model-using-LogisticRegression" data-toc-modified-id="Logistic-Regression-model-using-LogisticRegression-3.5.2"><span class="toc-item-num">3.5.2&nbsp;&nbsp;</span>Logistic Regression model using <a href="https://scikit-learn.org/stable/modules/generated/sklearn.linear_model.LogisticRegression.html" rel="nofollow" target="_blank">LogisticRegression</a></a></span></li><li><span><a href="#k-nn-model-using-KNeighborsClassifier" data-toc-modified-id="k-nn-model-using-KNeighborsClassifier-3.5.3"><span class="toc-item-num">3.5.3&nbsp;&nbsp;</span>k-nn model using <a href="https://scikit-learn.org/stable/modules/generated/sklearn.neighbors.KNeighborsClassifier.html" rel="nofollow" target="_blank">KNeighborsClassifier</a></a></span></li><li><span><a href="#SVM-Model--model-using-SVC" data-toc-modified-id="SVM-Model--model-using-SVC-3.5.4"><span class="toc-item-num">3.5.4&nbsp;&nbsp;</span>SVM Model  model using <a href="https://scikit-learn.org/stable/modules/generated/sklearn.svm.SVC.html" rel="nofollow" target="_blank">SVC</a></a></span></li><li><span><a href="#Decision-Trees-model-using-DecisionTreeClassifier" data-toc-modified-id="Decision-Trees-model-using-DecisionTreeClassifier-3.5.5"><span class="toc-item-num">3.5.5&nbsp;&nbsp;</span>Decision Trees model using <a href="https://scikit-learn.org/stable/modules/generated/sklearn.tree.DecisionTreeClassifier.html" rel="nofollow" target="_blank">DecisionTreeClassifier</a></a></span><ul class="toc-item"><li><span><a href="#Feature-Importance-in-DT" data-toc-modified-id="Feature-Importance-in-DT-3.5.5.1"><span class="toc-item-num">3.5.5.1&nbsp;&nbsp;</span>Feature Importance in DT</a></span></li><li><span><a href="#Visualize-the-Tree" data-toc-modified-id="Visualize-the-Tree-3.5.5.2"><span class="toc-item-num">3.5.5.2&nbsp;&nbsp;</span>Visualize the Tree</a></span></li><li><span><a href="#GridSearch-CV" data-toc-modified-id="GridSearch-CV-3.5.5.3"><span class="toc-item-num">3.5.5.3&nbsp;&nbsp;</span>GridSearch CV</a></span></li></ul></li><li><span><a href="#Random-forest-using-RandomForestClassifier" data-toc-modified-id="Random-forest-using-RandomForestClassifier-3.5.6"><span class="toc-item-num">3.5.6&nbsp;&nbsp;</span>Random forest using <a href="https://scikit-learn.org/stable/modules/generated/sklearn.ensemble.RandomForestClassifier.html" rel="nofollow" target="_blank">RandomForestClassifier</a></a></span></li></ul></li><li><span><a href="#Appendix" data-toc-modified-id="Appendix-3.6"><span class="toc-item-num">3.6&nbsp;&nbsp;</span>Appendix</a></span></li></ul></li><li><span><a href="#Reference-material-📚" data-toc-modified-id="Reference-material-📚-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Reference material 📚</a></span></li></ul></div>

# %% [markdown]
# <div class="alert alert-block alert-success">
#
# # Case Study 📓: Predict Cancellation
#
# [Case Study Link](https://docs.google.com/document/d/1DrkN30mmBapBX146OvhscGHtAnjqkWkO7scGCNnLqvc/edit#heading=h.wpciijalbsdh)
#
#
# </div>

# %% [markdown]
# ##  <font color= darkred> Import modules and data </font>

# %%
# data manipulation
import pandas as pd
import numpy as np

# data viz
import matplotlib.pyplot as plt
import seaborn as sns
# plt.style.use("fivethirtyeight") # styling the charts


# modeling 
from sklearn.tree import DecisionTreeClassifier
from sklearn import metrics
from sklearn import preprocessing

import warnings
warnings.filterwarnings('ignore')

print("All modules loaded")
# Out:
# All modules loaded

# %% [markdown]
# **Load Data**

# %%
url = 'https://raw.githubusercontent.com/vkoul/data/main/misc/hotel_bookings.csv'

# %time df = pd.read_csv(url)
# Out:
# CPU times: total: 266 ms
# Wall time: 20.2 s

# %% [markdown]
# ##  <font color= darkred> Data Inspection</font>🔍📊

# %% [markdown]
# ### <font color= darkred> Numerical inspection and summaries </font>

# %% [markdown]
# **Data Inspect**

# %%
df.head()
# Out:
#    no_of_adults  no_of_children  no_of_weekend_nights  no_of_week_nights  \
# 0             2               0                     1                  2
# 1             2               0                     2                  3
# 2             1               0                     2                  1
# 3             2               0                     0                  2
# 4             3               0                     0                  3
#
#   type_of_meal_plan  required_car_parking_space room_type_reserved  lead_time  \
# 0       Meal Plan 1                           0        Room_Type 1        224
# 1      Not Selected                           0        Room_Type 1          5
# 2       Meal Plan 1                           0        Room_Type 1          1
# 3       Meal Plan 1                           0        Room_Type 1        211
# 4      Not Selected                           0        Room_Type 1        277
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 56926 entries, 0 to 56925
# Data columns (total 18 columns):
#  #   Column                                Non-Null Count  Dtype
# ---  ------                                --------------  -----
#  0   no_of_adults                          56926 non-null  int64
#  1   no_of_children                        56926 non-null  int64
#  2   no_of_weekend_nights                  56926 non-null  int64
#  3   no_of_week_nights                     56926 non-null  int64
#  4   type_of_meal_plan                     56926 non-null  object
#  5   required_car_parking_space            56926 non-null  int64
#  6   room_type_reserved                    56926 non-null  object
#  7   lead_time                             56926 non-null  int64
#  8   arrival_year                          56926 non-null  int64
#  9   arrival_month                         56926 non-null  int64
#  10  arrival_date                          56926 non-null  int64
# ...

# %% [markdown]
# **Parsing the date columns properly**

# %%
df = pd.read_csv(url, parse_dates = {"arrival_complete_date": ["arrival_year", "arrival_month", "arrival_date"]})

# %%
df.shape
# Out:
# (56926, 16)

# %%
df.head()
# Out:
#   arrival_complete_date  no_of_adults  no_of_children  no_of_weekend_nights  \
# 0             2017 10 2             2               0                     1
# 1             2018 11 6             2               0                     2
# 2             2018 2 28             1               0                     2
# 3             2018 5 20             2               0                     0
# 4             2019 7 13             3               0                     0
#
#    no_of_week_nights type_of_meal_plan  required_car_parking_space  \
# 0                  2       Meal Plan 1                           0
# 1                  3      Not Selected                           0
# 2                  1       Meal Plan 1                           0
# 3                  2       Meal Plan 1                           0
# 4                  3      Not Selected                           0
#
#   room_type_reserved  lead_time market_segment_type  repeated_guest  \
# ...

# %%
df = df.query('arrival_complete_date != "2018 2 29"')

# %%
df['arrival_complete_date'] = pd.to_datetime(df['arrival_complete_date']).copy()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 56889 entries, 0 to 56925
# Data columns (total 16 columns):
#  #   Column                                Non-Null Count  Dtype
# ---  ------                                --------------  -----
#  0   arrival_complete_date                 56889 non-null  datetime64[ns]
#  1   no_of_adults                          56889 non-null  int64
#  2   no_of_children                        56889 non-null  int64
#  3   no_of_weekend_nights                  56889 non-null  int64
#  4   no_of_week_nights                     56889 non-null  int64
#  5   type_of_meal_plan                     56889 non-null  object
#  6   required_car_parking_space            56889 non-null  int64
#  7   room_type_reserved                    56889 non-null  object
#  8   lead_time                             56889 non-null  int64
#  9   market_segment_type                   56889 non-null  object
#  10  repeated_guest                        56889 non-null  int64
# ...

# %% [markdown]
# **🏡📝Task: Generating Booking Date**

# %%
df[['arrival_complete_date', 'lead_time']].head(2)
# Out:
#   arrival_complete_date  lead_time
# 0            2017-10-02        224
# 1            2018-11-06          5

# %%
# Write your code here

# %% [markdown]
# **Adding the components of date**

# %%
# day
df['day'] = df['arrival_complete_date'].dt.day

# week
df['week'] = df['arrival_complete_date'].dt.weekofyear

# month
df['month'] = df['arrival_complete_date'].dt.month

# year
df['year'] = df['arrival_complete_date'].dt.year

# month name
df['month_name'] = df['arrival_complete_date'].dt.month_name()

# day name
df['day_name'] = df['arrival_complete_date'].dt.day_name()

# %%
df.head()
# Out:
#   arrival_complete_date  no_of_adults  no_of_children  no_of_weekend_nights  \
# 0            2017-10-02             2               0                     1
# 1            2018-11-06             2               0                     2
# 2            2018-02-28             1               0                     2
# 3            2018-05-20             2               0                     0
# 4            2019-07-13             3               0                     0
#
#    no_of_week_nights type_of_meal_plan  required_car_parking_space  \
# 0                  2       Meal Plan 1                           0
# 1                  3      Not Selected                           0
# 2                  1       Meal Plan 1                           0
# 3                  2       Meal Plan 1                           0
# 4                  3      Not Selected                           0
#
#   room_type_reserved  lead_time market_segment_type  ...  \
# ...

# %% [markdown]
# **Missing values check**

# %%
df.isna().sum()
# Out:
# arrival_complete_date                   0
# no_of_adults                            0
# no_of_children                          0
# no_of_weekend_nights                    0
# no_of_week_nights                       0
# type_of_meal_plan                       0
# required_car_parking_space              0
# room_type_reserved                      0
# lead_time                               0
# market_segment_type                     0
# repeated_guest                          0
# no_of_previous_cancellations            0
# no_of_previous_bookings_not_canceled    0
# avg_price_per_room                      0
# no_of_special_requests                  0
# booking_status                          0
# day                                     0
# week                                    0
# month                                   0
# year                                    0
# month_name                              0
# day_name                                0
# dtype: int64

# %% [markdown]
# **Duplicates Check**

# %%
df.duplicated().sum()
# Out:
# 14348

# %%
df = df.drop_duplicates()

# %%
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# ##   <font color= darkred> EDA </font>

# %%
df.describe()
# Out:
#        no_of_adults  no_of_children  no_of_weekend_nights  no_of_week_nights  \
# count  42541.000000    42541.000000          42541.000000       42541.000000
# mean       1.917045        0.142122              0.895136           2.321149
# std        0.527394        0.459879              0.888166           1.519304
# min        0.000000        0.000000              0.000000           0.000000
# 25%        2.000000        0.000000              0.000000           1.000000
# 50%        2.000000        0.000000              1.000000           2.000000
# 75%        2.000000        0.000000              2.000000           3.000000
# max        4.000000       10.000000              8.000000          17.000000
#
#        required_car_parking_space     lead_time  repeated_guest  \
# count                42541.000000  42541.000000    42541.000000
# mean                     0.034320     77.347147        0.030817
# std                      0.182052     77.295238        0.172825
# ...

# %%
df.describe(include = 'object')
# Out:
#        type_of_meal_plan room_type_reserved market_segment_type  \
# count              42541              42541               42541
# unique                 4                  7                   5
# top          Meal Plan 1        Room_Type 1              Online
# freq               31832              29707               34149
#
#        booking_status month_name   day_name
# count           42541      42541      42541
# unique              2         12          7
# top      Not_Canceled     August  Wednesday
# freq            28061       5312       6765

# %%
df['avg_price_per_room'].plot(kind = 'kde', xlim = (0, 600));

# %% [markdown]
# **Dropping the rows with zero prices**

# %%
df = df[df['avg_price_per_room'] != 0].copy()

# %% [markdown]
# ### Univariate Analysis

# %% [markdown]
# **Understanding the cancelation rate**

# %%
df['booking_status'].value_counts(normalize= True).to_frame().style.format('{:.2%}')
# Out:
# <style type="text/css">
# </style>
# <table id="T_4b9a8">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_4b9a8_level0_col0" class="col_heading level0 col0" >booking_status</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_4b9a8_level0_row0" class="row_heading level0 row0" >Not_Canceled</th>
#       <td id="T_4b9a8_row0_col0" class="data row0 col0" >65.47%</td>
#     </tr>
#     <tr>
#       <th id="T_4b9a8_level0_row1" class="row_heading level0 row1" >Canceled</th>
#       <td id="T_4b9a8_row1_col0" class="data row1 col0" >34.53%</td>
#     </tr>
#   </tbody>
# </table>

# %%
df['booking_status'].value_counts(normalize= True).round(4).multiply(100).plot(kind = 'bar', backend = 'plotly')
# Out:
# <div>                            <div id="762124d8-f8c1-41f1-882b-5b326fec9c9f" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("762124d8-f8c1-41f1-882b-5b326fec9c9f")) {                    Plotly.newPlot(                        "762124d8-f8c1-41f1-882b-5b326fec9c9f",                        [{"alignmentgroup":"True","hovertemplate":"variable=booking_status<br>index=%{x}<br>value=%{y}<extra></extra>","legendgroup":"booking_status","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"booking_status","offsetgroup":"booking_status","orientation":"v","showlegend":true,"textposition":"auto","x":["Not_Canceled","Canceled"],"xaxis":"x","y":[65.47,34.53],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"bar":[{"error_x":{"color":
# ...

# %%
df['booking_status'] = df['booking_status'].replace({'Not_Canceled': 0,  'Canceled': 1})

# %%
df['booking_status'].value_counts(normalize= True).to_frame().style.format('{:.2%}')
# Out:
# <style type="text/css">
# </style>
# <table id="T_568ff">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_568ff_level0_col0" class="col_heading level0 col0" >booking_status</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_568ff_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_568ff_row0_col0" class="data row0 col0" >65.47%</td>
#     </tr>
#     <tr>
#       <th id="T_568ff_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_568ff_row1_col0" class="data row1 col0" >34.53%</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# **Daily Plot**

# %%
plt.figure(figsize= (10, 8))
sns.lineplot(data = df, x = 'arrival_complete_date', y = 'booking_status', markers = 'o', ci= False)
plt.title('Daily Cancellation Rate over time');

# %% [markdown]
# **Weekly Plot**

# %%
df.groupby(['year', 'week'])['booking_status'].mean().plot(kind = 'line', title = 'Weekly Cancellation Rate over time');

# %%
# # if we want to compare weeks across years
# sns.lineplot(data = df, x = 'week', y = 'booking_status', markers = 'o', ci= False, hue = 'year');

# %% [markdown]
# **Monthly Plot**

# %%
df.groupby(['year', 'month'])['booking_status'].mean().plot(kind = 'line', title = 'Cancellation Rate over time');

# %%
# # compare monthly
# sns.lineplot(data = df, x = 'month', y = 'booking_status', hue = 'year', ci = False);

# %% [markdown]
# ### Bivariate Analysis

# %%
drop_cols = ['day', 'week', 'month', 'year', 'required_car_parking_space']

# %%
corr = df.drop(columns = drop_cols, axis = 1).corr().round(3)

# plot the map
plt.figure(figsize= (15,8))
sns.heatmap(corr, annot= True);

# %%
ax = corr['booking_status'].sort_values()[:-1].plot(kind = 'bar', figsize = (10,6), title = 'Correlation Value Sorted')

ax.bar_label(ax.containers[0]);

# %%
# plotly interactive chart
# corr['booking_status'].sort_values()[:-1].plot(kind = 'bar', backend = 'plotly')

# %% [markdown]
# **Further Investigations**

# %%
df.groupby('booking_status')['lead_time'].mean().round()
# Out:
# booking_status
# 0     55.0
# 1    122.0
# Name: lead_time, dtype: float64

# %%
df.groupby('booking_status')['lead_time'].median().round()
# Out:
# booking_status
# 0     36.0
# 1    110.0
# Name: lead_time, dtype: float64

# %%
# combining the info
df.groupby('booking_status', as_index = False).agg({'lead_time': ['mean', 'median']}).round(2)
# Out:
#   booking_status lead_time
#                       mean median
# 0              0     54.79   36.0
# 1              1    122.40  110.0

# %%
# information using cross-tab
pd.crosstab(df['booking_status'], df['repeated_guest'], normalize= True).round(2)
# Out:
# repeated_guest     0     1
# booking_status
# 0               0.63  0.03
# 1               0.35  0.00

# %% [markdown]
# ##  <font color= darkred> Data Prep for Modeling </font>

# %% [markdown]
# ### Convert categorical value to numerical

# %% [markdown]
# * **[sklearn: `OneHotEncoder`](https://scikit-learn.org/stable/modules/generated/sklearn.preprocessing.OneHotEncoder.html)**
# * **[Pandas: `get_dummies()`](https://scikit-learn.org/stable/modules/generated/sklearn.preprocessing.OneHotEncoder.html)**

# %%
df['market_segment_type'].value_counts().plot(kind = 'bar', backend = 'plotly')
# Out:
# <div>                            <div id="c30f5f5c-663d-4d67-8006-cf5b435f43e5" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("c30f5f5c-663d-4d67-8006-cf5b435f43e5")) {                    Plotly.newPlot(                        "c30f5f5c-663d-4d67-8006-cf5b435f43e5",                        [{"alignmentgroup":"True","hovertemplate":"variable=market_segment_type<br>index=%{x}<br>value=%{y}<extra></extra>","legendgroup":"market_segment_type","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"market_segment_type","offsetgroup":"market_segment_type","orientation":"v","showlegend":true,"textposition":"auto","x":["Online","Offline","Corporate","Aviation","Complementary"],"xaxis":"x","y":[33965,5769,1933,195,38],"yaxis":"y","type":"bar"}],         
# ...

# %%
df['type_of_meal_plan'].value_counts().plot(kind = 'bar', backend = 'plotly')
# Out:
# <div>                            <div id="25a34818-4d7a-4be9-94a5-87caed67c827" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("25a34818-4d7a-4be9-94a5-87caed67c827")) {                    Plotly.newPlot(                        "25a34818-4d7a-4be9-94a5-87caed67c827",                        [{"alignmentgroup":"True","hovertemplate":"variable=type_of_meal_plan<br>index=%{x}<br>value=%{y}<extra></extra>","legendgroup":"type_of_meal_plan","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"type_of_meal_plan","offsetgroup":"type_of_meal_plan","orientation":"v","showlegend":true,"textposition":"auto","x":["Meal Plan 1","Not Selected","Meal Plan 2","Meal Plan 3"],"xaxis":"x","y":[31283,8666,1950,1],"yaxis":"y","type":"bar"}],                       
# ...

# %%
df['room_type_reserved'].value_counts().plot(kind = 'bar', backend = 'plotly')
# Out:
# <div>                            <div id="14bbc984-8a92-4c71-b463-82120955e178" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("14bbc984-8a92-4c71-b463-82120955e178")) {                    Plotly.newPlot(                        "14bbc984-8a92-4c71-b463-82120955e178",                        [{"alignmentgroup":"True","hovertemplate":"variable=room_type_reserved<br>index=%{x}<br>value=%{y}<extra></extra>","legendgroup":"room_type_reserved","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"room_type_reserved","offsetgroup":"room_type_reserved","orientation":"v","showlegend":true,"textposition":"auto","x":["Room_Type 1","Room_Type 4","Room_Type 6","Room_Type 5","Room_Type 2","Room_Type 7","Room_Type 3"],"xaxis":"x","y":[29266,9291,1513,877,692,
# ...

# %% [markdown]
# **Dropping the columns not relevant**

# %%
df.drop(columns = ['month_name', 'day_name', 'arrival_complete_date', 'year', 'month', 'day', 'arrival_complete_date'], inplace = True)

# %%
df = pd.get_dummies(df, drop_first=True)

# %%
# df.head()

# %% [markdown]
# ### Train-Test Split

# %%
# data prep
from sklearn.model_selection import train_test_split

# %%
# splitting the data 
X = df.drop(columns = 'booking_status')
y = df['booking_status']

# %%
# # doing train test split
x_train, x_test, y_train, y_test = train_test_split(X, y, test_size = 0.2, random_state = 2)

# %%
print("x_train: ", x_train.shape)
print("y_train: ", y_train.shape)


print("\n")

print("x_test: ", x_test.shape)
print("y_test: ", y_test.shape)

# display(x_train.head())
# display(y_train.head())
# Out:
# x_train:  (33520, 25)
# y_train:  (33520,)
#
#
# x_test:  (8380, 25)
# y_test:  (8380,)

# %% [markdown]
# ### Scaling

# %%
# x_train.select_dtypes(['int', 'float']).head()

# %%
to_be_scaled_cols = ['no_of_adults', 'no_of_children', 'lead_time', 'avg_price_per_room']

# %%
from sklearn.preprocessing import StandardScaler

# intiate 
scaler = StandardScaler()

# fit and transform 
x_train_scaled = scaler.fit_transform(x_train[to_be_scaled_cols])

# transform 
x_test_scaled = scaler.transform(x_test[to_be_scaled_cols])

# %%
type(x_test_scaled)
# Out:
# numpy.ndarray

# %%
x_train[to_be_scaled_cols].columns
# Out:
# Index(['no_of_adults', 'no_of_children', 'lead_time', 'avg_price_per_room'], dtype='object')

# %%
x_train_scaled = pd.DataFrame(x_test_scaled, columns = x_train[to_be_scaled_cols].columns)

# %%
# pre-scaling kde
x_train[to_be_scaled_cols].plot(kind = 'kde', subplots = True);

# %%
# post scaling kde
x_train_scaled.plot(kind = 'kde', subplots = True);

# %% [markdown]
# ## <font color= darkred> Model building </font> 💥⚡

# %% [markdown]
# **🚨Currently non-scaled data is being used, please used the scaled data and see if model predictions improve**

# %% [markdown]
# ### Dummy classifier model using [DummyClassifier](https://scikit-learn.org/stable/modules/generated/sklearn.dummy.DummyClassifier.html)

# %%
from sklearn.dummy import DummyClassifier

# %%
# call the model 
dummy = DummyClassifier()

# fit the model
dummy.fit(x_train, y_train)
# Out:
# DummyClassifier()

# %%
print("The accuracy score of the model for Train is {:.2f}".format(dummy.score(x_train, y_train)))

print("The accuracy score of the model for Test is {:.2f}".format(dummy.score(x_test, y_test)))
# Out:
# The accuracy score of the model for Train is 0.66
# The accuracy score of the model for Test is 0.65

# %% [markdown]
# ### Logistic Regression model using [LogisticRegression](https://scikit-learn.org/stable/modules/generated/sklearn.linear_model.LogisticRegression.html)

# %%
from sklearn.linear_model import LogisticRegression

# %%
# call the model 
lr = LogisticRegression()

# fit the model 
lr.fit(x_train, y_train)
# Out:
# LogisticRegression()

# %%
print("The accuracy score of the model for Train is {:.2f}".format(lr.score(x_train, y_train)))

print("The accuracy score of the model for test is {:.2f}".format(lr.score(x_test, y_test)))
# Out:
# The accuracy score of the model for Train is 0.79
# The accuracy score of the model for test is 0.79

# %% [markdown]
# ### k-nn model using [KNeighborsClassifier](https://scikit-learn.org/stable/modules/generated/sklearn.neighbors.KNeighborsClassifier.html)

# %%
from sklearn.neighbors import KNeighborsClassifier

# %%
# call the model
knn = KNeighborsClassifier()

# fit the model 
knn.fit(x_train, y_train)
# Out:
# KNeighborsClassifier()

# %% [markdown]
# **Train data predictions**

# %%
print("The accuracy score of the model for Train is {:.2f}".format(knn.score(x_train, y_train)))

print("The accuracy score of the model for test is {:.2f}".format(knn.score(x_test, y_test)))
# Out:
# The accuracy score of the model for Train is 0.83
# The accuracy score of the model for test is 0.73

# %% [markdown]
# ### SVM Model  model using [SVC](https://scikit-learn.org/stable/modules/generated/sklearn.svm.SVC.html)

# %%
from sklearn.svm import SVC

# %%
svc = SVC()

# fit the model 
svc.fit(x_train, y_train)
# Out:
# SVC()

# %%
print("The accuracy score of the model for Train is {:.2f}".format(svc.score(x_train, y_train)))

print("The accuracy score of the model for test is {:.2f}".format(svc.score(x_test, y_test)))
# Out:
# The accuracy score of the model for Train is 0.76
# The accuracy score of the model for test is 0.76

# %% [markdown]
# ### Decision Trees model using [DecisionTreeClassifier](https://scikit-learn.org/stable/modules/generated/sklearn.tree.DecisionTreeClassifier.html)

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
# call the model
dt = DecisionTreeClassifier()

# fit the model 
dt.fit(x_train, y_train)
# Out:
# DecisionTreeClassifier()

# %%
print("The accuracy score of the model for Train is {:.2f}".format(dt.score(x_train, y_train)))

print("The accuracy score of the model for test is {:.2f}".format(dt.score(x_test, y_test)))
# Out:
# The accuracy score of the model for Train is 1.00
# The accuracy score of the model for test is 0.79

# %% [markdown]
# #### Feature Importance in DT

# %%
# list of column name
feature_names = list(x_train.columns)

# get the importanc from the model
importances = dt.feature_importances_

# placement
indices = np.argsort(importances)

# plotting the figure
plt.figure(figsize = (8, 8))
plt.title("Decision Tree Feature Importance")

plt.barh(range(len(indices)), importances[indices], color="darkred", align="center")

plt.yticks(range(len(indices)), [feature_names[i] for i in indices])
plt.xlabel("Relative Importance")

plt.show()

# %% [markdown]
# #### Visualize the Tree

# %%
from sklearn import tree

# %%
features = list(x_train.columns)

plt.figure(figsize=(20,20))

tree.plot_tree(dt,feature_names= features,max_depth = 3, filled=True, fontsize= 9, node_ids = True, class_names= True)
plt.show()

# %%
# !pip install dtreeviz  
# https://github.com/parrt/dtreeviz

# %%
import dtreeviz

# %%
# vis = dtreeviz(
#     dt,
#     x_train,
#     y_train,
#     target_name= "Booking Statys",
#     feature_names= x_train.columns.to_list(),
# )

# vis.view()

# %% [markdown]
# #### GridSearch CV

# %%
from sklearn.model_selection import GridSearchCV

# %%
# define the parameters
params = {'max_leaf_nodes': list(range(2, 6))
          ,'min_samples_split': [2, 3, 4]
          ,'criterion':['gini','entropy']
          ,'max_depth':list(range(4,10))}

# check the params
params
# Out:
# {'max_leaf_nodes': [2, 3, 4, 5],
#  'min_samples_split': [2, 3, 4],
#  'criterion': ['gini', 'entropy'],
#  'max_depth': [4, 5, 6, 7, 8, 9]}

# %%
# intialise the GS CV
grid_search_cv = GridSearchCV(DecisionTreeClassifier(random_state=42), params, verbose=1, cv=3)

# fit the model
grid_search_cv.fit(x_train, y_train)
# Out:
# Fitting 3 folds for each of 144 candidates, totalling 432 fits
# GridSearchCV(cv=3, estimator=DecisionTreeClassifier(random_state=42),
#              param_grid={'criterion': ['gini', 'entropy'],
#                          'max_depth': [4, 5, 6, 7, 8, 9],
#                          'max_leaf_nodes': [2, 3, 4, 5],
#                          'min_samples_split': [2, 3, 4]},
#              verbose=1)

# %%
grid_search_cv.best_estimator_
# Out:
# DecisionTreeClassifier(max_depth=4, max_leaf_nodes=5, random_state=42)

# %%
gs_df = pd.DataFrame(grid_search_cv.cv_results_).sort_values(by = 'rank_test_score')
display(gs_df.head())
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 71       0.036764      0.004082         0.004583    9.792368e-04
# 59       0.033999      0.000816         0.004001    4.052337e-07
# 69       0.035347      0.001714         0.004083    1.450558e-04
# 70       0.034370      0.002676         0.003907    1.321761e-04
# 47       0.034675      0.000831         0.004502    5.052693e-04
#
#    param_criterion param_max_depth param_max_leaf_nodes  \
# 71            gini               9                    5
# 59            gini               8                    5
# 69            gini               9                    5
# 70            gini               9                    5
# 47            gini               7                    5
#
#    param_min_samples_split                                             params  \
# 71                       4  {'criterion': 'gini', 'max_depth': 9, 'max_lea...
# ...

# %% [markdown]
# **🏡📝Task:Please fit the model based on output of Decision Trees. Does this improve the prediction output?**

# %% [markdown]
# ### Random forest using [RandomForestClassifier](https://scikit-learn.org/stable/modules/generated/sklearn.ensemble.RandomForestClassifier.html)

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
# call the model 
rf = RandomForestClassifier()

# fit the model 
rf.fit(x_train, y_train)
# Out:
# RandomForestClassifier()

# %%
print("The accuracy score of the model for Train is {:.2f}".format(rf.score(x_train, y_train)))

print("The accuracy score of the model for test is {:.2f}".format(rf.score(x_test, y_test)))
# Out:
# The accuracy score of the model for Train is 1.00
# The accuracy score of the model for test is 0.83

# %% [markdown]
# ## Appendix

# %% [markdown]
# **GridSearch CV using k-nn**

# %% [markdown]
# ![Hyperparameter-tuning-using-five-fold-cross-validation-GridSearchCV.png](attachment:Hyperparameter-tuning-using-five-fold-cross-validation-GridSearchCV.png)

# %%
from sklearn.model_selection import GridSearchCV

# %%
k_range = list(range(1, 31))
param_grid = dict(n_neighbors=k_range)

# %%
# defining parameter range
grid = GridSearchCV(knn, param_grid, cv=10, scoring ='accuracy', return_train_score = False,verbose = 1)

# %%
# fitting the model for grid search
grid_search = grid.fit(x_train, y_train)
# Out:
# Fitting 10 folds for each of 30 candidates, totalling 300 fits

# %%
# show the best parameters
print(grid_search.best_params_)
# Out:
# {'n_neighbors': 26}

# %%
gs_results = pd.DataFrame(grid_search.cv_results_)

# %% [markdown]
# <div class="alert alert-block alert-success">
#
# # Reference material 📚
#
#
# * [Python Data Science Handbook](https://jakevdp.github.io/PythonDataScienceHandbook/): good book for hands on practice and codes.
# * [ISLR](https://www.statlearning.com/)- good coverage of the theory
#
# </div>
