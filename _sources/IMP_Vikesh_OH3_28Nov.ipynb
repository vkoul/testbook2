# %% [markdown]
# <div class="alert alert-block alert-success">
#
# # Imperial Business Analytics- 🐍 Python Primer 1
#
#  👨‍🏫 **Vikesh K**
#  📅 **[28-Nov-2022]** ⏰ **5pm UTC**
#  **Office Hour # 03**
#
#
#
# </div>

# %% [markdown]
#  💡  <span style='font-family:Georgia'>
#     <font color= darkred> ***Don't learn and then start, start and then learn - Anon***
#     </font> 💡

# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Imperial-Business-Analytics--🐍-Python-Primer-1" data-toc-modified-id="Imperial-Business-Analytics--🐍-Python-Primer-1-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Imperial Business Analytics- 🐍 Python Primer 1</a></span></li><li><span><a href="#OH-Agenda-📝" data-toc-modified-id="OH-Agenda-📝-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>OH Agenda 📝</a></span></li><li><span><a href="#▶️-Theory" data-toc-modified-id="▶️-Theory-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>▶️ Theory</a></span><ul class="toc-item"><li><span><a href="#Data-Structure-Summary" data-toc-modified-id="Data-Structure-Summary-3.1"><span class="toc-item-num">3.1&nbsp;&nbsp;</span>Data Structure Summary</a></span></li><li><span><a href="#Lists" data-toc-modified-id="Lists-3.2"><span class="toc-item-num">3.2&nbsp;&nbsp;</span>Lists</a></span></li><li><span><a href="#Tuples" data-toc-modified-id="Tuples-3.3"><span class="toc-item-num">3.3&nbsp;&nbsp;</span>Tuples</a></span></li><li><span><a href="#Dictionary" data-toc-modified-id="Dictionary-3.4"><span class="toc-item-num">3.4&nbsp;&nbsp;</span>Dictionary</a></span></li></ul></li><li><span><a href="#Exercises-💥⚡" data-toc-modified-id="Exercises-💥⚡-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Exercises 💥⚡</a></span><ul class="toc-item"><li><span><a href="#List" data-toc-modified-id="List-4.1"><span class="toc-item-num">4.1&nbsp;&nbsp;</span>List</a></span></li><li><span><a href="#Tuples" data-toc-modified-id="Tuples-4.2"><span class="toc-item-num">4.2&nbsp;&nbsp;</span>Tuples</a></span></li><li><span><a href="#Dictionary" data-toc-modified-id="Dictionary-4.3"><span class="toc-item-num">4.3&nbsp;&nbsp;</span>Dictionary</a></span></li></ul></li><li><span><a href="#Pandas🐼-Data-frame" data-toc-modified-id="Pandas🐼-Data-frame-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>Pandas🐼 Data-frame</a></span></li><li><span><a href="#Case-Study-📓---Titanic" data-toc-modified-id="Case-Study-📓---Titanic-6"><span class="toc-item-num">6&nbsp;&nbsp;</span>Case Study 📓 - Titanic</a></span></li><li><span><a href="#Further-Practice-🤿" data-toc-modified-id="Further-Practice-🤿-7"><span class="toc-item-num">7&nbsp;&nbsp;</span>Further Practice 🤿</a></span></li><li><span><a href="#Resources/Further-Reading-📚" data-toc-modified-id="Resources/Further-Reading-📚-8"><span class="toc-item-num">8&nbsp;&nbsp;</span>Resources/Further Reading 📚</a></span></li><li><span><a href="#[Optional]-🤯" data-toc-modified-id="[Optional]-🤯-9"><span class="toc-item-num">9&nbsp;&nbsp;</span>[Optional] 🤯</a></span><ul class="toc-item"><li><span><a href="#Memory-Block" data-toc-modified-id="Memory-Block-9.1"><span class="toc-item-num">9.1&nbsp;&nbsp;</span>Memory Block</a></span></li><li><span><a href="#Copying-and-aliasing-in-python" data-toc-modified-id="Copying-and-aliasing-in-python-9.2"><span class="toc-item-num">9.2&nbsp;&nbsp;</span>Copying and aliasing in python</a></span></li></ul></li></ul></div>

# %% [markdown]
# <div class="alert alert-block alert-success">
#
# # OH Agenda 📝
#
# * Data Structures
#     * List
#     * Dictionary
#     * Tuples
# * Pandas Intro
#     * Data analysis using Pandas
# * Exercises 💥⚡
#
# <div/>

# %% [markdown]
# # ▶️ Theory

# %% [markdown]
# <div class="alert alert-block alert-danger">
#
# ## Data Structure Summary
#
# ![data_structure_summary.JPG](attachment:data_structure_summary.JPG)

# %% [markdown]
# <div class="alert alert-block alert-danger">
#
#
# ## Lists
#
# * Lists are also ordered sequence
# * They can be modified
# * Lists can also contain multiple data types
# * Lists can be nested
# * List elements can be accesed via an index; also negative index
# * Index can also be used to slice the lists
# * You can contcatenate lists by combining them
#     * `l1 = [2 , 3]`
#     * `l2 = [5 , 6]`
#     * `l3 = l1 + l2`
# * `.extend()` method can be used to add elements to the list
#
#
#
# ## Tuples
#
# * Tuples are ordered sequence
#     * `height  = (5.11, 5.5, 5.8, 5.5)`
# * Different type of variables can be contained in a tuple, `str`, `int` etc.
# * The elements can be accesed via an index, staring from 0
#     * negative index can also be used
# * One can concatenate tuples by adding them
#     * `tuple1 = (2,3,4)`
#     * `tuple2 = tuple1 + (6,7)`
# * Once created, you can't manipulate a tuple. You will have to create a new tuple
# * Tuples can be nested. Tuples within tuples
#     * `nested_tuple = (1,2,("salt,"sugar"), (3,4))`
#
# ## Dictionary
#
# * A dictionary consists of ***keys*** and ***values***.
# * Compared to lists, instead of the numerical indexes, dictionaries have keys.
# * These keys are used to access values within a dictionary.
#
#     ![dictionary.png](attachment:dictionary.png)
#
# </div>

# %% [markdown]
# ![list.png](attachment:list.png)

# %% [markdown]
# # Exercises 💥⚡

# %% [markdown]
# <div class="alert alert-block alert-danger">
#
# **Some of the below exercises were discussed in the OH. Please try the rest on your own as homework exercises**

# %% [markdown]
# ## List

# %% [markdown]
# **Q Are lists mutable?**

# %%
x = [30, 40]
print(x)

x = [30,40,50]
print(x)

# %%
y = (30, 40)
print(id(y))
print(y)

# %%
y = (30, 40, 50)
print(id(y))
print(y)

# %% [markdown]
# **Q  What will be the result of `[1,2,3] + [1,1,1]`**
#
# *Hint*: The mathematical operations on `list` are very similar to how they work on `string`

# %% [markdown]
# **Q What will be the result of `x = [1,2,3] and x.extend([1,1,1])`**

# %%
z = [1,2,3]
print(z)
print(id(z))
print('--------')

z.extend([1,1,1])
print(z)
print(id(z))

# %% [markdown]
# You will notice that the memory location of z remains the same in the below example. This highlights the property that list are mutable

# %% [markdown]
# Visualise the steps on [here](http://www.pythontutor.com/visualize.html#code=x%20%3D%20%5B1,2,3%5D%0A%0Aprint%28x%29%0Aprint%28len%28x%29%29%0Aprint%28%22--------%22%29%0A%0A%23%20extending%20%0Ax.extend%28%5B1,1,1%5D%29%0Aprint%28x%29%0Aprint%28len%28x%29%29&cumulative=false&curInstr=7&heapPrimitives=nevernest&mode=display&origin=opt-frontend.js&py=3&rawInputLstJSON=%5B%5D&textReferences=false)

# %% [markdown]
# **Q What will be the result of `x = [1,2,3] and x.append([1,1,1])`**

# %% [markdown]
# Visualise the steps [here](http://www.pythontutor.com/visualize.html#code=x%20%3D%20%5B1,2,3%5D%0A%0Aprint%28x%29%0Aprint%28len%28x%29%29%0Aprint%28%22--------%22%29%0A%0A%23%20extending%20%0Ax.append%28%5B1,1,1%5D%29%0Aprint%28x%29&cumulative=false&curInstr=6&heapPrimitives=nevernest&mode=display&origin=opt-frontend.js&py=3&rawInputLstJSON=%5B%5D&textReferences=false)

# %% [markdown]
# **Q What will happen when we do `z = [2,3,4]`; `z[0] = 5`**

# %% [markdown]
# **Q On doing the below steps?**
#   * `q = [1,2,3]`
#   * `r = q`
#   * `r[0] = 9`
#
# **What will be `q[0]`?**

# %% [markdown]
# Visualize the steps [here](http://www.pythontutor.com/visualize.html#code=q%20%3D%20%5B1,2,3%5D%0Aq%0A%0Ar%20%3D%20q%0A%0Aprint%28r%29%0A%0Ar%5B0%5D%20%3D%209%0Aprint%28r%29%0A%0Aprint%28q%5B0%5D%29%0Aprint%28q%29&cumulative=false&curInstr=8&heapPrimitives=nevernest&mode=display&origin=opt-frontend.js&py=3&rawInputLstJSON=%5B%5D&textReferences=false)

# %% [markdown]
# **Q If `S` is a list what does the following syntax do: `T = S[:]`?**

# %% [markdown]
# Using the `[:]` creates a deep copy and then s and t are not referencing to the same memory block.
# Visualzise the steps [here](http://www.pythontutor.com/visualize.html#code=s%20%3D%20%5B1,2,3%5D%0Aprint%28s%29%0Aprint%28s%5B%3A%5D%29%0A%0A%0A%0At%20%3D%20s%5B%3A%5D%0Aprint%28t%29%0A%0At%5B0%5D%20%3D%209%0A%0Aprint%28s%5B0%5D%29&cumulative=false&curInstr=7&heapPrimitives=nevernest&mode=display&origin=opt-frontend.js&py=3&rawInputLstJSON=%5B%5D&textReferences=false)

# %% [markdown]
# **Q Consider the following list : `A = ["john",11,1.4]` . What will list `A` contain after the following command is run: `del(A[0])`?**

# %% [markdown]
# **Q In the list `L = [1,2,[3,'a'],[4,'b']]`. How to extract `'b'`?**

# %% [markdown]
# **Q What is the result of the following operation: `'P,Q,R,S'.split(',')`? What will be the type of the output?**

# %% [markdown]
# ## Tuples

# %% [markdown]
# **Q What is the result of the following: `len(("salt",10,1.2, "sugar",10))`**

# %% [markdown]
# **Q Consider the tuple `tuple_a = ("P","Q","R")`, what is the result of the following operation `tuple_a[-1]?`**

# %% [markdown]
# **Q Consider the `tuple A=((11,12),[21,22])`, that contains a tuple and list. What is the result of the following operation `A[1]`**

# %% [markdown]
# **Q Consider the `tuple A=((11,12),[21,22])`, that contains a tuple and list. What is the result of the following operation `A[0][1]`?**

# %% [markdown]
# ## Dictionary

# %% [markdown]
# Its important that the key of the dictionary, is immutable. hence it can only be a number, a string or a tuple

# %%
# Create a sample dictionary
release_year_dict = {(3): "1982",
                     "Back in Black": "1980", \
                    "The Dark Side of the Moon": "1973", 
                     "The Bodyguard": "1992", \
                    "Bat Out of Hell": "1977", 
                     "Their Greatest Hits (1971-1975)": "1976", \
                    "Saturday Night Fever": "1977", "Rumours": "1977"}
release_year_dict

# %%
# Get all the keys in dictionary
release_year_dict.keys()

# %%
# Get all the values in dictionary
release_year_dict.values()

# %% [markdown]
# **Add enteries** to the dictionary

# %%
# Append value with key into dictionary
release_year_dict['Graduation'] = '2007'
release_year_dict

# %% [markdown]
# **Delete enteries**

# %%
# Delete entries by key
del(release_year_dict['Thriller'])
del(release_year_dict['Graduation'])
release_year_dict

# %% [markdown]
# <div class="alert alert-block alert-danger">
#
# # Pandas🐼 Data-frame
#
# A pandas data frame has got three major attributes:
# * values
# * columns
# * index
#
# Dictionary and Pandas dataframe are inter-related and you can create a dataframe from dictionary

# %% [markdown]
# ![pandas_data_structure.JPG](attachment:pandas_data_structure.JPG)

# %% [markdown]
# <div class="alert alert-block alert-success">
#
# **Commonly used Pandas commands:**

# %% [markdown]
# ![pandas_function_summary.JPG](attachment:pandas_function_summary.JPG)

# %% [markdown]
# <div class="alert alert-block alert-success">
#
# **How `groupby()` function works in Pandas in the background**

# %% [markdown]
# ![split_apply_combine.png](attachment:split_apply_combine.png)

# %% [markdown]
# <div class="alert alert-block alert-info">
#
# # Case Study 📓 - Titanic
#
# ![titianic.jpg](attachment:titianic.jpg)

# %% [markdown]
# **Before you use the Pandas library (module), you need to call it. After calling it you will be able to use its different functions**

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# We will be using the `Titanic` dataset. Please click on the below link to see the file
#
# [Data Source](https://raw.githubusercontent.com/vkoul/data/main/misc/titanic.csv)

# %% [markdown]
# **How do we load data in Pandas?**

# %%
url = 'https://raw.githubusercontent.com/vkoul/data/main/misc/titanic.csv'

df = pd.read_csv(url)

print('This ran')

# %% [markdown]
# **How to look at the data**?

# %%
display(df)

# %% [markdown]
# **Elements of the data-frame**

# %%
df.columns

# %%
df.index

# %%
df.values

# %% [markdown]
# **Q - How do we get a snapshot of the loaded dataframe?**

# %%
df.info()

# %% [markdown]
# <div class="alert alert-block alert-danger">
#
# **`df.info()` is a useful function and allows us to see, the different columns, the non-missining enteries, the memory of the dataset and the different datatypes of the colummns**

# %% [markdown]
# **Q- How many rows and columns do we have?**

# %%
df.shape

# %% [markdown]
# **Q- How to check the initial and last few rows**

# %%
display(df.head(5))
display(df.tail(5))

# %% [markdown]
# **Q- Do we have any missing values**

# %%
df.isnull().sum()

# %%
df.isna().sum()

# %%
print(df.shape)
print(df.shape[0])
print(df.shape[1])

# %% [markdown]
# **Calculate the percentage of the missing values**

# %%
df.isna().sum()/df.shape[0] * 100

# %% [markdown]
# **Alternatively we can try:**

# %%
df.isna().mean()*100

# %% [markdown]
# **Q- How many men and women were on the ship?**

# %%
df.columns

# %%
type(df['Sex'])

# %% [markdown]
# Call the individual column

# %%
df['Sex']

# %%
type(df)

# %% [markdown]
# <div class="alert alert-block alert-danger">
#
# **A single column in pandas is called `series`. While the whole data is a dataframe**

# %%
df['Sex'].value_counts()

# %% [markdown]
# **Calculate the percentage**

# %%
df['Sex'].value_counts()/df.shape[0]

# %% [markdown]
# **Alternatively**

# %%
df['Sex'].value_counts(normalize = True) *100

# %% [markdown]
# **Q- How many passengers survived? Calculate the percentage of surviving passengers**

# %%
df.columns

# %%
df['Survived'].value_counts(normalize = True) # percantage terms

# %%
df['Survived'] == 1

# %% [markdown]
# **Filtering the data that meets the criteria:  `Survived  == 1`**

# %%
df[df['Survived'] == 1]

# %% [markdown]
# **Q- What is the share of first class passengers among all passengers?**

# %%
df.columns
df['Pclass'].value_counts(normalize = True).round(2)

# %% [markdown]
# **Q- How old were the passengers? Calculate the average and median age of the passengers**

# %%
df['Age'].mean()

# %%
df['Age'].median()

# %% [markdown]
# **We can make use of inbulit pandas plot capabilities to make plot basic charts**

# %% [markdown]
# **Histogram:**

# %%
df['Age'].plot(kind = 'hist');

# %% [markdown]
# **Density plot:**

# %%
df['Age'].plot(kind = 'kde');

# %% [markdown]
# **Q- What's the average age of men and women?**

# %% [markdown]
# <div class="alert alert-block alert-danger">
#
# To answer this, we would need to use `groupby()` function in Pandas. It will roll-up the data to a categorical level and then apply the numeric steps. In the background, it works on the principle of `Split-Apply-Combine` highlighted above in the image

# %%
df.groupby('Sex')['Age'].mean().round(2)

# %% [markdown]
# This shows, on average, females were younger than males on the titanic ship

# %% [markdown]
# **Q- What is the average fare?**

# %%
df['Fare'].mean()

# %%
df['Fare'].median()

# %%
df['Fare'].plot(kind = 'hist');

# %%
df['Fare'].plot(kind = 'kde');

# %% [markdown]
# **Q- What is the average fare per class?**
#
# *Hint: You can use `groupby()` function*

# %% [markdown]
# <div class="alert alert-block alert-danger">
#
# # Further Practice 🤿
#
# [**Please practise your pandas skills**](https://github.com/guipsamora/pandas_exercises)

# %% [markdown]
# <div class="alert alert-block alert-success">
#
# # Resources/Further Reading 📚
#
#
# * **[Python Tutor](http://www.pythontutor.com/)** - A very good website to visualise the steps in Python. This is helpful to develop intuition behind the steps
#
# **Data Structure in Python**
#
#
# * **[Python for Aspiring Data Scientists](https://towardsdatascience.com/data-structures-in-python-python-for-aspiring-data-scientists-b52bc058fcbd)**
#
# * **[Python List](https://www.programiz.com/python-programming/list)**
#
# * **[Python Tuple](https://www.programiz.com/python-programming/tuple)**
#
# * **[Python Dictionary](https://www.programiz.com/python-programming/dictionary)**
#
# **Pandas**
#
# * **[10 mins pandas](https://pandas.pydata.org/pandas-docs/stable/user_guide/10min.html)** - Definitely check this out to get a quick introduction to pandas
#
# * **[Data Manipulation with Pandas](https://jakevdp.github.io/PythonDataScienceHandbook/03.00-introduction-to-pandas.html)**
#
#
# </div>

# %% [markdown]
# <div class="alert alert-block alert-info">
#
# # [Optional] 🤯
#
# ## Memory Block
#
# * Python uses your RAM to store the objects that you create in a session
# * We can make use of the `id()` function to get the address of an object in python. This is an integer
# * Knowing this is very helpful when you want to understand if python is creating a copy of the object or just another reference.
# * Short-cut way to check if two python objects have the same address = `is` command
#
# * if you define `x = 30`, you can visualise below what will happen in the memory
#
#
# ![computer_memory.JPG](attachment:computer_memory.JPG)

# %% [markdown]
# Python has a **memory efficient process** running in the background. The variables are a reference to the object and not the object itself.
#
# That means, if you save a number (for example 30) in python with variable `x` and later with `y`. The `x` and `y` will refer to the same place in memory

# %%
# save x = 30 
x = 30 
print("memory location of x :", id(x))

# now save 30 with y 
y = 30
print("memory location of y :", id(y))

# the memory address of x and y are same, as they refer to the same location in memory

# %% [markdown]
# ## Copying and aliasing in python

# %%
# aliasing a list

a = [1,2,3]
b = a

print("a's address", id(a))
print("b's address", id(b))

print(a is b)

# %% [markdown]
# The address of `a` and `b` will be same, as they both refer to the same object.
#
# **You can visualise the steps at this [link](http://www.pythontutor.com/visualize.html#code=%0Aa%20%3D%20%5B1,2,3%5D%0Ab%20%3D%20a%0A%0Aprint%28%22a's%20address%22,%20id%28a%29%29%0Aprint%28%22b's%20address%22,%20id%28b%29%29%0A%0Aprint%28a%20is%20b%29&cumulative=false&curInstr=0&heapPrimitives=nevernest&mode=display&origin=opt-frontend.js&py=3&rawInputLstJSON=%5B%5D&textReferences=false)**

# %%
# copying a list 
a = [1,2,3]
b = a[:]

print("a's address", id(a))
print("b's address", id(b))

print(a is b)

# %% [markdown]
# The address of `a` and `b` will be different now, as they refer to different objects in python.
#
# **You can visualise the steps at this [link](http://www.pythontutor.com/visualize.html#code=%23%20copying%20a%20list%20%0Aa%20%3D%20%5B1,2,3%5D%0Ab%20%3D%20a%5B%3A%5D%0A%0Aprint%28%22a's%20address%22,%20id%28a%29%29%0Aprint%28%22b's%20address%22,%20id%28b%29%29%0A%0Aprint%28a%20is%20b%29&cumulative=false&curInstr=3&heapPrimitives=nevernest&mode=display&origin=opt-frontend.js&py=3&rawInputLstJSON=%5B%5D&textReferences=false)**
